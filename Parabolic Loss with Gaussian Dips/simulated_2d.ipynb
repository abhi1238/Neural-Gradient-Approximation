# %%
import sys
sys.path.append("../")

# %% [markdown]
# ##### import library

# %%
# Standard libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle

# 3D plotting
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits import mplot3d
from matplotlib.colors import Normalize, LinearSegmentedColormap

# Machine learning and preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons

# Deep learning (PyTorch and TensorFlow)
import torch
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, BatchNormalization, LeakyReLU
from tensorflow.keras.regularizers import l2

# Plotly for interactive visualization
import plotly.graph_objects as go

# Custom utility module
import utility
# Out:
# 2025-04-08 16:56:53.425147: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-08 16:56:53.509236: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-08 16:56:53.509280: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-08 16:56:53.510926: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-08 16:56:53.522691: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-08 16:56:54.495319: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ##### Define functions

# %%
def parabolic_loss_with_dips_3D(args):
    x, y = args
    base_parabola = x**2 + y**2
    
    dips = sum(
        10 * np.exp(-5 * ((x - i) ** 2 + (y - j) ** 2))
        for i in list(range(-5, -2)) + list(range(3, 6))  
        for j in list(range(-5, -2)) + list(range(3, 6))   
    )
    
    return base_parabola - dips


f = parabolic_loss_with_dips_3D

# %% [markdown]
# ##### Define the fitness function for PyGAD

# %%
def fitness_func(ga_instance, solution, solution_idx):
    return -parabolic_loss_with_dips_3D(solution)

# %% [markdown]
# ##### Define the function in PyTorch

# %%
def parabolic_loss_with_dips_3D_torch(args):
    x, y = args
    base_parabola = x**2 + y**2

    dips = sum(
        10 * torch.exp(-5 * ((x - i) ** 2 + (y - j) ** 2))
        for i in list(range(-5, -2)) + list(range(3, 6))  
        for j in list(range(-5, -2)) + list(range(3, 6))   
    )

    return base_parabola - dips

# %% [markdown]
# ##### Plot graph

# %%
def plot_graph(fig, x, y, z):

    # 3D Surface Plot
    ax1 = fig.add_subplot(1, 1, 1, projection='3d')
    surf = ax1.plot_surface(x, y, z, cmap=cmap, edgecolor="none")
    ax1.set_title("3D Surface Plot", fontsize=10)
    ax1.set_xlabel("X-axis", fontsize=10)
    ax1.set_ylabel("Y-axis", fontsize=10)
    # ax1.set_zlabel("Function Value", fontsize=5)

    # Add colorbar for 3D plot
    cbar1 = fig.colorbar(surf, ax=ax1, fraction=0.046, pad=0.04)
    cbar1.set_label("Function Value", fontsize=10)

    # # 2D Contour Plot
    # ax2 = fig.add_subplot(1, 2, 2)
    # contour = ax2.contourf(x, y, z, levels=50, cmap=cmap)
    # ax2.set_xlabel("X-axis", fontsize=10)
    # ax2.set_ylabel("Y-axis", fontsize=10)
    # ax2.set_title("2D Contour Plot", fontsize=10)

    # # Add colorbar for 2D plot without overlapping
    # cbar2 = fig.colorbar(contour, ax=ax2, fraction=0.046, pad=0.04)
    # cbar2.set_label("Function Value", fontsize=10)

    ax1.tick_params(axis='x', labelsize=10, rotation=0)
    ax1.tick_params(axis='y', labelsize=10)
    ax1.tick_params(axis='both', which='both', width=0.5)

    # Improve layout to avoid overlap
    plt.tight_layout()
    # plt.show()

    return fig, ax1

# %% [markdown]
# ##### Initialize class object and grid

# %%
obj = utility.CentralDifference()
# Create a grid of x and y values
interval = 1000
max_iters = 1000
min_grid = -5
max_grid = 5
x = np.linspace(min_grid, max_grid, interval)
y = np.linspace(min_grid, max_grid, interval)
x, y = np.meshgrid(x, y)
z = f((x, y))

# %% [markdown]
# ##### Define colormap

# %%
colors = [
    (0.0, "navy"),         # Deep blue for the minimum
    (0.01, "blue"),         # Blue
    (0.2, "cyan"),         # Cyan
    (0.4, "limegreen"),    # Green
    (0.6, "yellow"),       # Yellow
    (0.8, "orange"),       # Orange
    (1.0, "darkred"),      # Deep red for the maximum
]
cmap = LinearSegmentedColormap.from_list("improved_gradient_cmap", colors)

# obj.show_2D_surface_plot(x, y, z,  title = "Custom function", cmap = cmap)

# %% [markdown]
# ##### Show 3D visualization and contourplot

# %%
# fig = plt.figure(figsize=(12, 6), dpi=300)
# fig, ax1, ax2 = plot_graph(fig, x, y, z)
# # plt.savefig("sample3.pdf", dpi = 300)

# %%
fig = plt.figure(figsize=(4, 4), dpi=300)
fig, ax1 = plot_graph(fig, x, y, z)

ax1.set_ylabel("y-axis", labelpad=1)
ax1.set_xlabel("x-axis", labelpad=1)
ax1.set_title("3D surface plot", fontsize=10)
ax1 = utility.custom_figure_axis(ax=ax1, show_ticks = True, rotation =0, tick_fontsize = 5, label_fontsize = 5, legend_fontsize = 5)

# ax2.set_ylabel("y-axis", labelpad=1)
# ax2.set_xlabel("x-axis", labelpad=1)
# ax2.set_title("2D contour plot", fontsize=10)
# ax2 = utility.custom_figure_axis(ax=ax2, show_ticks = True, rotation =0, tick_fontsize = 10, label_fontsize = 10, legend_fontsize = 10)
ax1.grid()
# plt.savefig("simulated_2d_3d.pdf", dpi = 300, bbox_inches="tight")

# %% [markdown]
# ##### SHow a dummy example

# %%
args = [-0.16210637, -0.11185439]

grad = obj.compute_gradient(args = args, f = f)
print("Gradient:", grad)
# Out:
# Gradient: [-0.32421274 -0.22370878]

# %% [markdown]
# ##### Define parametrs and variables

# %%
num_samples=5000
dimension=2
batch_size=512

# %% [markdown]
# ##### Generate synthetic data to model the gradient of function with min and max grid

# %%
X_train, X_test, y_train, y_test = obj.generate_random_data(f=f, num_samples=num_samples, dimension=dimension, value_range=(min_grid,max_grid))

# %% [markdown]
# ##### Define model architecture

# %%
model = Sequential([
    Dense(128, input_shape=(dimension,), activation='leaky_relu'),
    Dense(64, activation='leaky_relu', kernel_regularizer=l2(0.001)),
    # Dense(8, activation='leaky_relu'),
    Dense(dimension)
])

model.compile(loss='mae', optimizer = tf.keras.optimizers.Adam(learning_rate=0.001))

epochs = 2000

history = model.fit(X_train, y_train, validation_split=0.2, epochs=epochs, batch_size=batch_size, verbose=1)
# Out:
# Epoch 1/2000
# 7/7 [==============================] - 1s 26ms/step - loss: 4.9645 - val_loss: 4.6019
# Epoch 2/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 4.4046 - val_loss: 4.0117
# Epoch 3/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 3.8339 - val_loss: 3.3895
# Epoch 4/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 3.2451 - val_loss: 2.7432
# Epoch 5/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.6539 - val_loss: 2.2192
# Epoch 6/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.4888 - val_loss: 2.3034
# Epoch 7/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.4067 - val_loss: 2.2108
# Epoch 8/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.3977 - val_loss: 2.1915
# Epoch 9/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.3512 - val_loss: 2.1572
# Epoch 10/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.3410 - val_loss: 2.1458
# Epoch 11/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.3308 - val_loss: 2.1344
# Epoch 12/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.3249 - val_loss: 2.1283
# Epoch 13/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.3195 - val_loss: 2.1250
# Epoch 14/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3152 - val_loss: 2.1230
# Epoch 15/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3122 - val_loss: 2.1189
# Epoch 16/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.3092 - val_loss: 2.1170
# Epoch 17/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 2.3066 - val_loss: 2.1154
# Epoch 18/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3057 - val_loss: 2.1149
# Epoch 19/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.3049 - val_loss: 2.1136
# Epoch 20/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.3037 - val_loss: 2.1144
# Epoch 21/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.3039 - val_loss: 2.1082
# Epoch 22/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3009 - val_loss: 2.1071
# Epoch 23/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2978 - val_loss: 2.1083
# Epoch 24/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2969 - val_loss: 2.1070
# Epoch 25/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2955 - val_loss: 2.1053
# Epoch 26/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2940 - val_loss: 2.1038
# Epoch 27/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2933 - val_loss: 2.1024
# Epoch 28/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2931 - val_loss: 2.1023
# Epoch 29/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2921 - val_loss: 2.1034
# Epoch 30/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2909 - val_loss: 2.1001
# Epoch 31/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2887 - val_loss: 2.0986
# Epoch 32/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2880 - val_loss: 2.1004
# Epoch 33/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2891 - val_loss: 2.0991
# Epoch 34/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2886 - val_loss: 2.0967
# Epoch 35/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2855 - val_loss: 2.0947
# Epoch 36/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2845 - val_loss: 2.0954
# Epoch 37/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2845 - val_loss: 2.0958
# Epoch 38/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2845 - val_loss: 2.0950
# Epoch 39/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2841 - val_loss: 2.0901
# Epoch 40/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2816 - val_loss: 2.0939
# Epoch 41/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2830 - val_loss: 2.0911
# Epoch 42/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2819 - val_loss: 2.0919
# Epoch 43/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2816 - val_loss: 2.0896
# Epoch 44/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2790 - val_loss: 2.0887
# Epoch 45/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2790 - val_loss: 2.0881
# Epoch 46/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2791 - val_loss: 2.0896
# Epoch 47/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2787 - val_loss: 2.0909
# Epoch 48/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2787 - val_loss: 2.0889
# Epoch 49/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2763 - val_loss: 2.0875
# Epoch 50/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2771 - val_loss: 2.0863
# Epoch 51/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2748 - val_loss: 2.0872
# Epoch 52/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2747 - val_loss: 2.0862
# Epoch 53/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2747 - val_loss: 2.0855
# Epoch 54/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2740 - val_loss: 2.0841
# Epoch 55/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2730 - val_loss: 2.0841
# Epoch 56/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2739 - val_loss: 2.0836
# Epoch 57/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2739 - val_loss: 2.0854
# Epoch 58/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2734 - val_loss: 2.0874
# Epoch 59/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2733 - val_loss: 2.0886
# Epoch 60/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2736 - val_loss: 2.0856
# Epoch 61/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2708 - val_loss: 2.0802
# Epoch 62/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2698 - val_loss: 2.0830
# Epoch 63/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2705 - val_loss: 2.0787
# Epoch 64/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2701 - val_loss: 2.0835
# Epoch 65/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2707 - val_loss: 2.0807
# Epoch 66/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2692 - val_loss: 2.0798
# Epoch 67/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2699 - val_loss: 2.0796
# Epoch 68/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2687 - val_loss: 2.0798
# Epoch 69/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2667 - val_loss: 2.0776
# Epoch 70/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2660 - val_loss: 2.0774
# Epoch 71/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2657 - val_loss: 2.0847
# Epoch 72/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2678 - val_loss: 2.0815
# Epoch 73/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2684 - val_loss: 2.0796
# Epoch 74/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2684 - val_loss: 2.0775
# Epoch 75/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2674 - val_loss: 2.0769
# Epoch 76/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2645 - val_loss: 2.0762
# Epoch 77/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2620 - val_loss: 2.0739
# Epoch 78/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2611 - val_loss: 2.0733
# Epoch 79/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2621 - val_loss: 2.0775
# Epoch 80/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2648 - val_loss: 2.0752
# Epoch 81/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2629 - val_loss: 2.0739
# Epoch 82/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2615 - val_loss: 2.0747
# Epoch 83/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2613 - val_loss: 2.0760
# Epoch 84/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2611 - val_loss: 2.0768
# Epoch 85/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2615 - val_loss: 2.0722
# Epoch 86/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2590 - val_loss: 2.0711
# Epoch 87/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2594 - val_loss: 2.0746
# Epoch 88/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2611 - val_loss: 2.0733
# Epoch 89/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2589 - val_loss: 2.0711
# Epoch 90/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2588 - val_loss: 2.0701
# Epoch 91/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2573 - val_loss: 2.0692
# Epoch 92/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2572 - val_loss: 2.0701
# Epoch 93/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2573 - val_loss: 2.0676
# Epoch 94/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2552 - val_loss: 2.0710
# Epoch 95/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2561 - val_loss: 2.0717
# Epoch 96/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2580 - val_loss: 2.0730
# Epoch 97/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2575 - val_loss: 2.0668
# Epoch 98/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2553 - val_loss: 2.0674
# Epoch 99/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2543 - val_loss: 2.0662
# Epoch 100/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2534 - val_loss: 2.0665
# Epoch 101/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2550 - val_loss: 2.0704
# Epoch 102/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2545 - val_loss: 2.0693
# Epoch 103/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2554 - val_loss: 2.0678
# Epoch 104/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2545 - val_loss: 2.0695
# Epoch 105/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2560 - val_loss: 2.0730
# Epoch 106/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2553 - val_loss: 2.0648
# Epoch 107/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2527 - val_loss: 2.0683
# Epoch 108/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2540 - val_loss: 2.0650
# Epoch 109/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2510 - val_loss: 2.0637
# Epoch 110/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2509 - val_loss: 2.0618
# Epoch 111/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2523 - val_loss: 2.0656
# Epoch 112/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2530 - val_loss: 2.0667
# Epoch 113/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2531 - val_loss: 2.0692
# Epoch 114/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2548 - val_loss: 2.0727
# Epoch 115/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2561 - val_loss: 2.0676
# Epoch 116/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2511 - val_loss: 2.0675
# Epoch 117/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2499 - val_loss: 2.0626
# Epoch 118/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2488 - val_loss: 2.0621
# Epoch 119/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2487 - val_loss: 2.0614
# Epoch 120/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2478 - val_loss: 2.0611
# Epoch 121/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2469 - val_loss: 2.0629
# Epoch 122/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2473 - val_loss: 2.0618
# Epoch 123/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2473 - val_loss: 2.0625
# Epoch 124/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2479 - val_loss: 2.0592
# Epoch 125/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2462 - val_loss: 2.0589
# Epoch 126/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2451 - val_loss: 2.0599
# Epoch 127/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2449 - val_loss: 2.0579
# Epoch 128/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2454 - val_loss: 2.0592
# Epoch 129/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2480 - val_loss: 2.0587
# Epoch 130/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2460 - val_loss: 2.0604
# Epoch 131/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2449 - val_loss: 2.0599
# Epoch 132/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2444 - val_loss: 2.0581
# Epoch 133/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2442 - val_loss: 2.0572
# Epoch 134/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2455 - val_loss: 2.0607
# Epoch 135/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2448 - val_loss: 2.0639
# Epoch 136/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2472 - val_loss: 2.0625
# Epoch 137/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2460 - val_loss: 2.0611
# Epoch 138/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2443 - val_loss: 2.0575
# Epoch 139/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2438 - val_loss: 2.0555
# Epoch 140/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2451 - val_loss: 2.0610
# Epoch 141/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2473 - val_loss: 2.0599
# Epoch 142/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2435 - val_loss: 2.0605
# Epoch 143/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2444 - val_loss: 2.0624
# Epoch 144/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2473 - val_loss: 2.0571
# Epoch 145/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2447 - val_loss: 2.0543
# Epoch 146/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2429 - val_loss: 2.0575
# Epoch 147/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2427 - val_loss: 2.0578
# Epoch 148/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2442 - val_loss: 2.0590
# Epoch 149/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2440 - val_loss: 2.0555
# Epoch 150/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2421 - val_loss: 2.0553
# Epoch 151/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2403 - val_loss: 2.0539
# Epoch 152/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2401 - val_loss: 2.0539
# Epoch 153/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2395 - val_loss: 2.0542
# Epoch 154/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2388 - val_loss: 2.0603
# Epoch 155/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2405 - val_loss: 2.0556
# Epoch 156/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2394 - val_loss: 2.0588
# Epoch 157/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2417 - val_loss: 2.0612
# Epoch 158/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2418 - val_loss: 2.0541
# Epoch 159/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2404 - val_loss: 2.0528
# Epoch 160/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2374 - val_loss: 2.0556
# Epoch 161/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2394 - val_loss: 2.0552
# Epoch 162/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2391 - val_loss: 2.0550
# Epoch 163/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2382 - val_loss: 2.0556
# Epoch 164/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2388 - val_loss: 2.0507
# Epoch 165/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2364 - val_loss: 2.0533
# Epoch 166/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2373 - val_loss: 2.0532
# Epoch 167/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2376 - val_loss: 2.0506
# Epoch 168/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2389 - val_loss: 2.0527
# Epoch 169/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2367 - val_loss: 2.0496
# Epoch 170/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2359 - val_loss: 2.0527
# Epoch 171/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2377 - val_loss: 2.0541
# Epoch 172/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2369 - val_loss: 2.0530
# Epoch 173/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2361 - val_loss: 2.0525
# Epoch 174/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2385 - val_loss: 2.0518
# Epoch 175/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2362 - val_loss: 2.0519
# Epoch 176/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2353 - val_loss: 2.0493
# Epoch 177/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2343 - val_loss: 2.0478
# Epoch 178/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2320 - val_loss: 2.0495
# Epoch 179/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2341 - val_loss: 2.0494
# Epoch 180/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2334 - val_loss: 2.0514
# Epoch 181/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2345 - val_loss: 2.0490
# Epoch 182/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2342 - val_loss: 2.0482
# Epoch 183/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2328 - val_loss: 2.0469
# Epoch 184/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2320 - val_loss: 2.0485
# Epoch 185/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2317 - val_loss: 2.0493
# Epoch 186/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2346 - val_loss: 2.0467
# Epoch 187/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2324 - val_loss: 2.0468
# Epoch 188/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2327 - val_loss: 2.0518
# Epoch 189/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2337 - val_loss: 2.0473
# Epoch 190/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2323 - val_loss: 2.0482
# Epoch 191/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2339 - val_loss: 2.0474
# Epoch 192/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2321 - val_loss: 2.0483
# Epoch 193/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2321 - val_loss: 2.0463
# Epoch 194/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2305 - val_loss: 2.0453
# Epoch 195/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2318 - val_loss: 2.0488
# Epoch 196/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2320 - val_loss: 2.0491
# Epoch 197/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2308 - val_loss: 2.0490
# Epoch 198/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2342 - val_loss: 2.0518
# Epoch 199/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2350 - val_loss: 2.0476
# Epoch 200/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2334 - val_loss: 2.0492
# Epoch 201/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2326 - val_loss: 2.0508
# Epoch 202/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2321 - val_loss: 2.0478
# Epoch 203/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2301 - val_loss: 2.0436
# Epoch 204/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2284 - val_loss: 2.0452
# Epoch 205/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2300 - val_loss: 2.0451
# Epoch 206/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2305 - val_loss: 2.0459
# Epoch 207/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2318 - val_loss: 2.0447
# Epoch 208/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2290 - val_loss: 2.0459
# Epoch 209/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2304 - val_loss: 2.0486
# Epoch 210/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2302 - val_loss: 2.0482
# Epoch 211/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2285 - val_loss: 2.0466
# Epoch 212/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2295 - val_loss: 2.0460
# Epoch 213/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2288 - val_loss: 2.0450
# Epoch 214/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2292 - val_loss: 2.0436
# Epoch 215/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2275 - val_loss: 2.0416
# Epoch 216/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2255 - val_loss: 2.0423
# Epoch 217/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2247 - val_loss: 2.0413
# Epoch 218/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2250 - val_loss: 2.0431
# Epoch 219/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2257 - val_loss: 2.0449
# Epoch 220/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2265 - val_loss: 2.0432
# Epoch 221/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2270 - val_loss: 2.0455
# Epoch 222/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2281 - val_loss: 2.0455
# Epoch 223/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2275 - val_loss: 2.0435
# Epoch 224/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2257 - val_loss: 2.0455
# Epoch 225/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2265 - val_loss: 2.0426
# Epoch 226/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2263 - val_loss: 2.0403
# Epoch 227/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2247 - val_loss: 2.0422
# Epoch 228/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2234 - val_loss: 2.0402
# Epoch 229/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2234 - val_loss: 2.0407
# Epoch 230/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2226 - val_loss: 2.0402
# Epoch 231/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2233 - val_loss: 2.0419
# Epoch 232/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2234 - val_loss: 2.0404
# Epoch 233/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2233 - val_loss: 2.0413
# Epoch 234/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2236 - val_loss: 2.0411
# Epoch 235/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2230 - val_loss: 2.0378
# Epoch 236/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2227 - val_loss: 2.0423
# Epoch 237/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2243 - val_loss: 2.0419
# Epoch 238/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2246 - val_loss: 2.0469
# Epoch 239/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2266 - val_loss: 2.0413
# Epoch 240/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2246 - val_loss: 2.0413
# Epoch 241/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2254 - val_loss: 2.0426
# Epoch 242/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2251 - val_loss: 2.0389
# Epoch 243/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2229 - val_loss: 2.0403
# Epoch 244/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2215 - val_loss: 2.0396
# Epoch 245/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2210 - val_loss: 2.0386
# Epoch 246/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2209 - val_loss: 2.0389
# Epoch 247/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2218 - val_loss: 2.0420
# Epoch 248/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2227 - val_loss: 2.0429
# Epoch 249/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2225 - val_loss: 2.0392
# Epoch 250/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2230 - val_loss: 2.0402
# Epoch 251/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2227 - val_loss: 2.0443
# Epoch 252/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2224 - val_loss: 2.0414
# Epoch 253/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2229 - val_loss: 2.0401
# Epoch 254/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2222 - val_loss: 2.0425
# Epoch 255/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2221 - val_loss: 2.0397
# Epoch 256/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2219 - val_loss: 2.0412
# Epoch 257/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2256 - val_loss: 2.0395
# Epoch 258/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2248 - val_loss: 2.0410
# Epoch 259/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2237 - val_loss: 2.0392
# Epoch 260/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2234 - val_loss: 2.0401
# Epoch 261/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2233 - val_loss: 2.0410
# Epoch 262/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2271 - val_loss: 2.0392
# Epoch 263/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2210 - val_loss: 2.0404
# Epoch 264/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2214 - val_loss: 2.0374
# Epoch 265/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2213 - val_loss: 2.0477
# Epoch 266/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2244 - val_loss: 2.0450
# Epoch 267/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2265 - val_loss: 2.0409
# Epoch 268/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2212 - val_loss: 2.0391
# Epoch 269/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2210 - val_loss: 2.0362
# Epoch 270/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2195 - val_loss: 2.0356
# Epoch 271/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2189 - val_loss: 2.0373
# Epoch 272/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2184 - val_loss: 2.0351
# Epoch 273/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2173 - val_loss: 2.0357
# Epoch 274/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2180 - val_loss: 2.0350
# Epoch 275/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2177 - val_loss: 2.0349
# Epoch 276/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2164 - val_loss: 2.0339
# Epoch 277/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2171 - val_loss: 2.0349
# Epoch 278/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2185 - val_loss: 2.0347
# Epoch 279/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2188 - val_loss: 2.0370
# Epoch 280/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2187 - val_loss: 2.0386
# Epoch 281/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2194 - val_loss: 2.0387
# Epoch 282/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2221 - val_loss: 2.0386
# Epoch 283/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2200 - val_loss: 2.0374
# Epoch 284/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2189 - val_loss: 2.0359
# Epoch 285/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2196 - val_loss: 2.0418
# Epoch 286/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2206 - val_loss: 2.0405
# Epoch 287/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2223 - val_loss: 2.0403
# Epoch 288/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2225 - val_loss: 2.0362
# Epoch 289/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2215 - val_loss: 2.0387
# Epoch 290/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2201 - val_loss: 2.0401
# Epoch 291/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2200 - val_loss: 2.0412
# Epoch 292/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2217 - val_loss: 2.0336
# Epoch 293/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2199 - val_loss: 2.0427
# Epoch 294/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2233 - val_loss: 2.0375
# Epoch 295/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2196 - val_loss: 2.0331
# Epoch 296/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2173 - val_loss: 2.0362
# Epoch 297/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2157 - val_loss: 2.0354
# Epoch 298/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2167 - val_loss: 2.0348
# Epoch 299/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2154 - val_loss: 2.0314
# Epoch 300/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2149 - val_loss: 2.0334
# Epoch 301/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2150 - val_loss: 2.0307
# Epoch 302/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2125 - val_loss: 2.0324
# Epoch 303/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2134 - val_loss: 2.0314
# Epoch 304/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2126 - val_loss: 2.0315
# Epoch 305/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2137 - val_loss: 2.0316
# Epoch 306/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2143 - val_loss: 2.0304
# Epoch 307/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2143 - val_loss: 2.0331
# Epoch 308/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2138 - val_loss: 2.0324
# Epoch 309/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2149 - val_loss: 2.0350
# Epoch 310/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2166 - val_loss: 2.0346
# Epoch 311/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2157 - val_loss: 2.0357
# Epoch 312/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2187 - val_loss: 2.0372
# Epoch 313/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2170 - val_loss: 2.0326
# Epoch 314/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2152 - val_loss: 2.0325
# Epoch 315/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2162 - val_loss: 2.0364
# Epoch 316/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2171 - val_loss: 2.0367
# Epoch 317/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2157 - val_loss: 2.0341
# Epoch 318/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2145 - val_loss: 2.0383
# Epoch 319/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2178 - val_loss: 2.0413
# Epoch 320/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2193 - val_loss: 2.0334
# Epoch 321/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2151 - val_loss: 2.0343
# Epoch 322/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2157 - val_loss: 2.0326
# Epoch 323/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2151 - val_loss: 2.0347
# Epoch 324/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2148 - val_loss: 2.0327
# Epoch 325/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2146 - val_loss: 2.0298
# Epoch 326/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2132 - val_loss: 2.0332
# Epoch 327/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2122 - val_loss: 2.0285
# Epoch 328/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2129 - val_loss: 2.0309
# Epoch 329/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2133 - val_loss: 2.0346
# Epoch 330/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2150 - val_loss: 2.0330
# Epoch 331/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2156 - val_loss: 2.0336
# Epoch 332/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2143 - val_loss: 2.0321
# Epoch 333/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2135 - val_loss: 2.0296
# Epoch 334/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2113 - val_loss: 2.0326
# Epoch 335/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2108 - val_loss: 2.0270
# Epoch 336/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2094 - val_loss: 2.0267
# Epoch 337/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2095 - val_loss: 2.0305
# Epoch 338/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2111 - val_loss: 2.0331
# Epoch 339/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2123 - val_loss: 2.0292
# Epoch 340/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2114 - val_loss: 2.0366
# Epoch 341/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2134 - val_loss: 2.0280
# Epoch 342/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2118 - val_loss: 2.0344
# Epoch 343/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2127 - val_loss: 2.0349
# Epoch 344/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2165 - val_loss: 2.0381
# Epoch 345/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2157 - val_loss: 2.0386
# Epoch 346/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2143 - val_loss: 2.0288
# Epoch 347/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2121 - val_loss: 2.0258
# Epoch 348/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2082 - val_loss: 2.0265
# Epoch 349/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2081 - val_loss: 2.0301
# Epoch 350/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2086 - val_loss: 2.0304
# Epoch 351/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2090 - val_loss: 2.0282
# Epoch 352/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2082 - val_loss: 2.0295
# Epoch 353/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2100 - val_loss: 2.0287
# Epoch 354/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2073 - val_loss: 2.0275
# Epoch 355/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2069 - val_loss: 2.0271
# Epoch 356/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2085 - val_loss: 2.0336
# Epoch 357/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2112 - val_loss: 2.0350
# Epoch 358/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2113 - val_loss: 2.0296
# Epoch 359/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2104 - val_loss: 2.0282
# Epoch 360/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2089 - val_loss: 2.0315
# Epoch 361/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2079 - val_loss: 2.0285
# Epoch 362/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2080 - val_loss: 2.0301
# Epoch 363/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2077 - val_loss: 2.0258
# Epoch 364/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2066 - val_loss: 2.0261
# Epoch 365/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 2.2073 - val_loss: 2.0330
# Epoch 366/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2111 - val_loss: 2.0325
# Epoch 367/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2108 - val_loss: 2.0284
# Epoch 368/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2079 - val_loss: 2.0310
# Epoch 369/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2072 - val_loss: 2.0260
# Epoch 370/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2069 - val_loss: 2.0297
# Epoch 371/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2075 - val_loss: 2.0265
# Epoch 372/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2056 - val_loss: 2.0267
# Epoch 373/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2059 - val_loss: 2.0312
# Epoch 374/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 2.2063 - val_loss: 2.0290
# Epoch 375/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2085 - val_loss: 2.0272
# Epoch 376/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2071 - val_loss: 2.0292
# Epoch 377/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2078 - val_loss: 2.0278
# Epoch 378/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2052 - val_loss: 2.0295
# Epoch 379/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2086 - val_loss: 2.0379
# Epoch 380/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2129 - val_loss: 2.0307
# Epoch 381/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2077 - val_loss: 2.0272
# Epoch 382/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2048 - val_loss: 2.0296
# Epoch 383/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2046 - val_loss: 2.0231
# Epoch 384/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2035 - val_loss: 2.0226
# Epoch 385/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2039 - val_loss: 2.0229
# Epoch 386/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2051 - val_loss: 2.0315
# Epoch 387/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2073 - val_loss: 2.0247
# Epoch 388/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2052 - val_loss: 2.0242
# Epoch 389/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2047 - val_loss: 2.0226
# Epoch 390/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2022 - val_loss: 2.0209
# Epoch 391/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2037 - val_loss: 2.0252
# Epoch 392/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2029 - val_loss: 2.0219
# Epoch 393/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2021 - val_loss: 2.0245
# Epoch 394/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2028 - val_loss: 2.0211
# Epoch 395/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2031 - val_loss: 2.0251
# Epoch 396/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2061 - val_loss: 2.0303
# Epoch 397/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2077 - val_loss: 2.0234
# Epoch 398/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2050 - val_loss: 2.0257
# Epoch 399/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2043 - val_loss: 2.0226
# Epoch 400/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2029 - val_loss: 2.0242
# Epoch 401/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2037 - val_loss: 2.0241
# Epoch 402/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2028 - val_loss: 2.0253
# Epoch 403/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2048 - val_loss: 2.0261
# Epoch 404/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2061 - val_loss: 2.0267
# Epoch 405/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2054 - val_loss: 2.0270
# Epoch 406/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2059 - val_loss: 2.0237
# Epoch 407/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2053 - val_loss: 2.0254
# Epoch 408/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2054 - val_loss: 2.0352
# Epoch 409/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2090 - val_loss: 2.0302
# Epoch 410/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2083 - val_loss: 2.0286
# Epoch 411/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2050 - val_loss: 2.0203
# Epoch 412/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2023 - val_loss: 2.0241
# Epoch 413/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2017 - val_loss: 2.0249
# Epoch 414/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2026 - val_loss: 2.0239
# Epoch 415/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2028 - val_loss: 2.0221
# Epoch 416/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2049 - val_loss: 2.0244
# Epoch 417/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2046 - val_loss: 2.0249
# Epoch 418/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2026 - val_loss: 2.0218
# Epoch 419/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2030 - val_loss: 2.0251
# Epoch 420/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2024 - val_loss: 2.0213
# Epoch 421/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2020 - val_loss: 2.0222
# Epoch 422/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2015 - val_loss: 2.0203
# Epoch 423/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2026 - val_loss: 2.0207
# Epoch 424/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2019 - val_loss: 2.0193
# Epoch 425/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2028 - val_loss: 2.0219
# Epoch 426/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2025 - val_loss: 2.0248
# Epoch 427/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2012 - val_loss: 2.0220
# Epoch 428/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2006 - val_loss: 2.0186
# Epoch 429/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1984 - val_loss: 2.0211
# Epoch 430/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1980 - val_loss: 2.0188
# Epoch 431/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1988 - val_loss: 2.0244
# Epoch 432/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2017 - val_loss: 2.0256
# Epoch 433/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2028 - val_loss: 2.0212
# Epoch 434/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2001 - val_loss: 2.0197
# Epoch 435/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1990 - val_loss: 2.0195
# Epoch 436/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1989 - val_loss: 2.0209
# Epoch 437/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1982 - val_loss: 2.0172
# Epoch 438/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1982 - val_loss: 2.0214
# Epoch 439/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1979 - val_loss: 2.0261
# Epoch 440/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1994 - val_loss: 2.0251
# Epoch 441/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2001 - val_loss: 2.0245
# Epoch 442/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2008 - val_loss: 2.0253
# Epoch 443/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2006 - val_loss: 2.0213
# Epoch 444/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2009 - val_loss: 2.0202
# Epoch 445/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1989 - val_loss: 2.0218
# Epoch 446/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1980 - val_loss: 2.0243
# Epoch 447/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2013 - val_loss: 2.0281
# Epoch 448/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2004 - val_loss: 2.0235
# Epoch 449/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1982 - val_loss: 2.0230
# Epoch 450/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1990 - val_loss: 2.0233
# Epoch 451/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1987 - val_loss: 2.0199
# Epoch 452/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1974 - val_loss: 2.0199
# Epoch 453/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1990 - val_loss: 2.0251
# Epoch 454/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1998 - val_loss: 2.0237
# Epoch 455/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2006 - val_loss: 2.0261
# Epoch 456/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2042 - val_loss: 2.0213
# Epoch 457/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2013 - val_loss: 2.0266
# Epoch 458/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2030 - val_loss: 2.0237
# Epoch 459/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2009 - val_loss: 2.0181
# Epoch 460/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1967 - val_loss: 2.0182
# Epoch 461/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1955 - val_loss: 2.0194
# Epoch 462/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1966 - val_loss: 2.0178
# Epoch 463/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1981 - val_loss: 2.0213
# Epoch 464/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1993 - val_loss: 2.0240
# Epoch 465/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2010 - val_loss: 2.0253
# Epoch 466/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1996 - val_loss: 2.0207
# Epoch 467/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1976 - val_loss: 2.0193
# Epoch 468/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1958 - val_loss: 2.0211
# Epoch 469/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1959 - val_loss: 2.0191
# Epoch 470/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1973 - val_loss: 2.0188
# Epoch 471/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1978 - val_loss: 2.0220
# Epoch 472/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1978 - val_loss: 2.0182
# Epoch 473/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1978 - val_loss: 2.0187
# Epoch 474/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1966 - val_loss: 2.0182
# Epoch 475/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1951 - val_loss: 2.0165
# Epoch 476/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1947 - val_loss: 2.0178
# Epoch 477/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1965 - val_loss: 2.0155
# Epoch 478/2000
# ...
# Epoch 1844/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1297 - val_loss: 1.9828
# Epoch 1845/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1284 - val_loss: 1.9858
# Epoch 1846/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1329 - val_loss: 1.9776
# Epoch 1847/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1313 - val_loss: 1.9882
# Epoch 1848/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1315 - val_loss: 1.9789
# Epoch 1849/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1248 - val_loss: 1.9751
# Epoch 1850/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1234 - val_loss: 1.9819
# Epoch 1851/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.1288 - val_loss: 1.9860
# Epoch 1852/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1322 - val_loss: 1.9832
# Epoch 1853/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1309 - val_loss: 1.9838
# Epoch 1854/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1315 - val_loss: 1.9959
# Epoch 1855/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1380 - val_loss: 1.9882
# Epoch 1856/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1382 - val_loss: 1.9837
# Epoch 1857/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1346 - val_loss: 1.9883
# Epoch 1858/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1345 - val_loss: 1.9768
# Epoch 1859/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1275 - val_loss: 1.9852
# Epoch 1860/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1329 - val_loss: 1.9873
# Epoch 1861/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1318 - val_loss: 1.9950
# Epoch 1862/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1328 - val_loss: 1.9792
# Epoch 1863/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1275 - val_loss: 1.9815
# Epoch 1864/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1290 - val_loss: 1.9864
# Epoch 1865/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1353 - val_loss: 1.9914
# Epoch 1866/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1319 - val_loss: 1.9848
# Epoch 1867/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1326 - val_loss: 1.9853
# Epoch 1868/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1331 - val_loss: 1.9880
# Epoch 1869/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1327 - val_loss: 1.9884
# Epoch 1870/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1317 - val_loss: 1.9824
# Epoch 1871/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1292 - val_loss: 1.9851
# Epoch 1872/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1318 - val_loss: 1.9854
# Epoch 1873/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1321 - val_loss: 1.9809
# Epoch 1874/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1326 - val_loss: 1.9910
# Epoch 1875/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1359 - val_loss: 1.9988
# Epoch 1876/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1340 - val_loss: 1.9781
# Epoch 1877/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1278 - val_loss: 1.9830
# Epoch 1878/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1290 - val_loss: 1.9868
# Epoch 1879/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1335 - val_loss: 1.9887
# Epoch 1880/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1296 - val_loss: 1.9775
# Epoch 1881/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1281 - val_loss: 1.9859
# Epoch 1882/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1333 - val_loss: 1.9751
# Epoch 1883/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1321 - val_loss: 1.9938
# Epoch 1884/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1355 - val_loss: 1.9999
# Epoch 1885/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1372 - val_loss: 1.9856
# Epoch 1886/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1319 - val_loss: 1.9779
# Epoch 1887/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1276 - val_loss: 1.9813
# Epoch 1888/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1268 - val_loss: 1.9890
# Epoch 1889/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1317 - val_loss: 1.9814
# Epoch 1890/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1316 - val_loss: 1.9791
# Epoch 1891/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1295 - val_loss: 1.9856
# Epoch 1892/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1363 - val_loss: 1.9847
# Epoch 1893/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1325 - val_loss: 1.9878
# Epoch 1894/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1349 - val_loss: 1.9899
# Epoch 1895/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1325 - val_loss: 1.9837
# Epoch 1896/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1319 - val_loss: 1.9805
# Epoch 1897/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1311 - val_loss: 1.9848
# Epoch 1898/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1350 - val_loss: 1.9954
# Epoch 1899/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1462 - val_loss: 1.9899
# Epoch 1900/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1440 - val_loss: 1.9956
# Epoch 1901/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1360 - val_loss: 1.9887
# Epoch 1902/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1313 - val_loss: 1.9813
# Epoch 1903/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1290 - val_loss: 1.9942
# Epoch 1904/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1353 - val_loss: 1.9801
# Epoch 1905/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1312 - val_loss: 1.9884
# Epoch 1906/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1323 - val_loss: 1.9801
# Epoch 1907/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1306 - val_loss: 1.9799
# Epoch 1908/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.1299 - val_loss: 1.9761
# Epoch 1909/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1308 - val_loss: 1.9882
# Epoch 1910/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1321 - val_loss: 1.9815
# Epoch 1911/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1304 - val_loss: 1.9772
# Epoch 1912/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1330 - val_loss: 1.9934
# Epoch 1913/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1387 - val_loss: 1.9922
# Epoch 1914/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1417 - val_loss: 1.9835
# Epoch 1915/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1383 - val_loss: 1.9986
# Epoch 1916/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1405 - val_loss: 2.0027
# Epoch 1917/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1436 - val_loss: 1.9973
# Epoch 1918/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.1361 - val_loss: 1.9919
# Epoch 1919/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1314 - val_loss: 1.9858
# Epoch 1920/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1299 - val_loss: 1.9781
# Epoch 1921/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1326 - val_loss: 1.9925
# Epoch 1922/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1377 - val_loss: 1.9815
# Epoch 1923/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1349 - val_loss: 2.0040
# Epoch 1924/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1417 - val_loss: 2.0042
# Epoch 1925/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1428 - val_loss: 1.9869
# Epoch 1926/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1364 - val_loss: 1.9840
# Epoch 1927/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1356 - val_loss: 1.9925
# Epoch 1928/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1395 - val_loss: 1.9884
# Epoch 1929/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1363 - val_loss: 1.9827
# Epoch 1930/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1322 - val_loss: 1.9817
# Epoch 1931/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1324 - val_loss: 1.9827
# Epoch 1932/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1309 - val_loss: 1.9824
# Epoch 1933/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1267 - val_loss: 1.9793
# Epoch 1934/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1286 - val_loss: 1.9821
# Epoch 1935/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1293 - val_loss: 1.9864
# Epoch 1936/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1298 - val_loss: 1.9813
# Epoch 1937/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.1285 - val_loss: 1.9787
# Epoch 1938/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1262 - val_loss: 1.9807
# Epoch 1939/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1263 - val_loss: 1.9848
# Epoch 1940/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.1300 - val_loss: 1.9834
# Epoch 1941/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1303 - val_loss: 1.9800
# Epoch 1942/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1283 - val_loss: 1.9846
# Epoch 1943/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1281 - val_loss: 1.9878
# Epoch 1944/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1318 - val_loss: 1.9801
# Epoch 1945/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1399 - val_loss: 1.9808
# Epoch 1946/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1328 - val_loss: 1.9869
# Epoch 1947/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1321 - val_loss: 1.9816
# Epoch 1948/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1300 - val_loss: 1.9903
# Epoch 1949/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1382 - val_loss: 1.9868
# Epoch 1950/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1347 - val_loss: 1.9795
# Epoch 1951/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1304 - val_loss: 1.9832
# Epoch 1952/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1315 - val_loss: 1.9844
# Epoch 1953/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1318 - val_loss: 1.9892
# Epoch 1954/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1302 - val_loss: 1.9799
# Epoch 1955/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1294 - val_loss: 1.9839
# Epoch 1956/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1301 - val_loss: 1.9875
# Epoch 1957/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1329 - val_loss: 1.9823
# Epoch 1958/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1361 - val_loss: 1.9816
# Epoch 1959/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1397 - val_loss: 2.0128
# Epoch 1960/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1402 - val_loss: 2.0002
# Epoch 1961/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1367 - val_loss: 1.9891
# Epoch 1962/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.1342 - val_loss: 1.9932
# Epoch 1963/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1373 - val_loss: 1.9991
# Epoch 1964/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1446 - val_loss: 1.9981
# Epoch 1965/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.1471 - val_loss: 1.9872
# Epoch 1966/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1342 - val_loss: 1.9866
# Epoch 1967/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1273 - val_loss: 1.9770
# Epoch 1968/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1246 - val_loss: 1.9752
# Epoch 1969/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1271 - val_loss: 1.9885
# Epoch 1970/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1341 - val_loss: 1.9833
# Epoch 1971/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1311 - val_loss: 1.9856
# Epoch 1972/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1334 - val_loss: 1.9955
# Epoch 1973/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1374 - val_loss: 2.0032
# Epoch 1974/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1437 - val_loss: 1.9895
# Epoch 1975/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1377 - val_loss: 1.9903
# Epoch 1976/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1360 - val_loss: 1.9879
# Epoch 1977/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1354 - val_loss: 1.9846
# Epoch 1978/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1358 - val_loss: 1.9867
# Epoch 1979/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1289 - val_loss: 1.9797
# Epoch 1980/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1300 - val_loss: 1.9882
# Epoch 1981/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1347 - val_loss: 1.9846
# Epoch 1982/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1299 - val_loss: 1.9811
# Epoch 1983/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1266 - val_loss: 1.9824
# Epoch 1984/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1305 - val_loss: 2.0013
# Epoch 1985/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 2.1385 - val_loss: 1.9918
# Epoch 1986/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1340 - val_loss: 1.9734
# Epoch 1987/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1279 - val_loss: 1.9822
# Epoch 1988/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1260 - val_loss: 1.9780
# Epoch 1989/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1270 - val_loss: 1.9801
# Epoch 1990/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1304 - val_loss: 1.9839
# Epoch 1991/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1314 - val_loss: 1.9847
# Epoch 1992/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1288 - val_loss: 1.9879
# Epoch 1993/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1290 - val_loss: 1.9836
# Epoch 1994/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1295 - val_loss: 1.9831
# Epoch 1995/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1313 - val_loss: 1.9919
# Epoch 1996/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1344 - val_loss: 1.9776
# Epoch 1997/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1333 - val_loss: 1.9878
# Epoch 1998/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1354 - val_loss: 1.9939
# Epoch 1999/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1380 - val_loss: 1.9834
# Epoch 2000/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1326 - val_loss: 1.9780

# %% [markdown]
# ##### Define loss curve

# %%
ax = obj.plot_convergence(history)
# ax = utility.custom_figure_axis(ax, fontsize=4, rotation = 0)
ax.set_ylabel("Loss", labelpad=1)
ax.set_xlabel("Epoch", labelpad=1)
ax.set_title("Loss curve", fontsize=10)

ax = utility.custom_figure_axis(ax, show_ticks = True, rotation =0, tick_fontsize = 10, label_fontsize = 10, legend_fontsize = 10)

plt.savefig("simulated_2d_loss.pdf", dpi = 300)

# %% [markdown]
# ##### Test data performance

# %%
test_loss = model.evaluate(X_test, y_test)
print("Test loss:", test_loss)
# Out:
#  1/32 [..............................] - ETA: 0s - loss: 2.8928
# 32/32 [==============================] - 0s 2ms/step - loss: 2.0308
# Test loss: 2.0308215618133545

# %% [markdown]
# ##### Define torch optimizer

# %%
import numpy as np
import torch
import torch.optim as optim

def torch_optimization(args, lr, num_steps, f, tol=1e-5, patience=100):
    """
    Performs optimization using PyTorch's Adam optimizer with early stopping 
    when loss difference is below a threshold for a given number of epochs.

    Parameters:
    args (tuple): Initial values (x, y).
    lr (float): Learning rate.
    num_steps (int): Maximum number of optimization steps.
    f (function): Function to be minimized.
    tol (float): Threshold for stopping when loss difference is small.
    patience (int): Number of consecutive epochs with small loss change before stopping.

    Returns:
    np.array: Optimized values of (x, y).
    list: List of function values (loss) at each epoch.
    """

    x = torch.tensor(args[0], dtype=torch.float32, requires_grad=True)
    y = torch.tensor(args[1], dtype=torch.float32, requires_grad=True)

    optimizer = optim.Adam([x, y], lr=lr)

    function_values = []  # Store f(x, y) values at each epoch
    stable_count = 0  # Counter for consecutive small changes

    for step in range(num_steps):
        optimizer.zero_grad()
        
        loss = f((x, y))  # Compute function value
        function_values.append(loss.item())  # Store function value
        
        loss.backward()  # Compute gradients
        optimizer.step()  # Update parameters

        # Check for early stopping
        if step > 0:
            loss_diff = abs(function_values[-1] - function_values[-2])
            if loss_diff < tol:
                stable_count += 1
            else:
                stable_count = 0  # Reset if loss difference is significant

            if stable_count >= patience:
                print(f"Early stopping at step {step} (loss change < {tol} for {patience} consecutive epochs)")
                break

    return np.array([x.item(), y.item()]), function_values

# %%
max_iters = 10000
lr = 0.001

# %% [markdown]
# ##### Store the result of Gradient Descent with central differentiation

# %%
c = 0

df_cd = pd.DataFrame(columns =["X_start",  "y_start", "X_gd_cd", "y_gd_cd"])

for i in list(range(-5, 6, 1)):
    for j in list(range(-5, 6, 1)):

        print(f"currently running for x = {i} and y = {j}")
        x0 = np.array([i*1.0, j*1.0])
        X_gd, y_gd, history_gd = obj.optimize_function_with_central_difference(f=f, x0=x0, learning_rate=lr, max_iters=max_iters, tol=1e-6, patience =200)
        df_cd.loc[c, ["X_gd_cd", "y_gd_cd"]] = X_gd, y_gd
        df_cd.loc[c, "y_start"] = f(x0)
        df_cd.loc[c, "X_start"] = x0


        c = c + 1

        X_gd, y_gd, x0 =  [None] * 3
# Out:
# currently running for x = -5 and y = -5
# Early stopping at iteration 308 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = -4
# Early stopping at iteration 292 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = -3
# Early stopping at iteration 282 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = -2
# Early stopping at iteration 3113 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = -1
# Early stopping at iteration 3085 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = 0
# Early stopping at iteration 3076 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = 1
# Early stopping at iteration 3085 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = 2
# Early stopping at iteration 3113 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = 3
# Early stopping at iteration 282 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = 4
# Early stopping at iteration 292 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = 5
# Early stopping at iteration 308 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = -5
# Early stopping at iteration 292 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = -4
# Early stopping at iteration 280 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = -3
# Early stopping at iteration 271 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = -2
# Early stopping at iteration 3021 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = -1
# Early stopping at iteration 2979 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = 0
# Early stopping at iteration 2964 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = 1
# Early stopping at iteration 2979 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = 2
# Early stopping at iteration 3021 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = 3
# Early stopping at iteration 271 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = 4
# Early stopping at iteration 280 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = 5
# Early stopping at iteration 292 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = -5
# Early stopping at iteration 282 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = -4
# Early stopping at iteration 271 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = -3
# Early stopping at iteration 258 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = -2
# Early stopping at iteration 2914 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = -1
# Early stopping at iteration 2847 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = 0
# Early stopping at iteration 2820 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = 1
# Early stopping at iteration 2847 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = 2
# Early stopping at iteration 2914 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = 3
# Early stopping at iteration 258 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = 4
# Early stopping at iteration 271 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = 5
# Early stopping at iteration 282 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = -5
# Early stopping at iteration 3113 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = -4
# Early stopping at iteration 3021 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = -3
# Early stopping at iteration 2914 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = -2
# Early stopping at iteration 2791 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = -1
# Early stopping at iteration 2674 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = 0
# Early stopping at iteration 2618 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = 1
# Early stopping at iteration 2674 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = 2
# Early stopping at iteration 2791 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = 3
# Early stopping at iteration 2914 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = 4
# Early stopping at iteration 3021 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = 5
# Early stopping at iteration 3113 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = -5
# Early stopping at iteration 3085 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = -4
# Early stopping at iteration 2979 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = -3
# Early stopping at iteration 2847 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = -2
# Early stopping at iteration 2674 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = -1
# Early stopping at iteration 2445 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = 0
# Early stopping at iteration 2272 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = 1
# Early stopping at iteration 2445 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = 2
# Early stopping at iteration 2674 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = 3
# Early stopping at iteration 2847 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = 4
# Early stopping at iteration 2979 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = 5
# Early stopping at iteration 3085 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = -5
# Early stopping at iteration 3076 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = -4
# Early stopping at iteration 2964 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = -3
# Early stopping at iteration 2820 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = -2
# Early stopping at iteration 2618 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = -1
# Early stopping at iteration 2272 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = 0
# Early stopping at iteration 200 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = 1
# Early stopping at iteration 2272 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = 2
# Early stopping at iteration 2618 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = 3
# Early stopping at iteration 2820 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = 4
# Early stopping at iteration 2964 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = 5
# Early stopping at iteration 3076 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = -5
# Early stopping at iteration 3085 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = -4
# Early stopping at iteration 2979 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = -3
# Early stopping at iteration 2847 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = -2
# Early stopping at iteration 2674 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = -1
# Early stopping at iteration 2445 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = 0
# Early stopping at iteration 2272 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = 1
# Early stopping at iteration 2445 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = 2
# Early stopping at iteration 2674 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = 3
# Early stopping at iteration 2847 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = 4
# Early stopping at iteration 2979 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = 5
# Early stopping at iteration 3085 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = -5
# Early stopping at iteration 3113 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = -4
# Early stopping at iteration 3021 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = -3
# Early stopping at iteration 2914 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = -2
# Early stopping at iteration 2791 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = -1
# Early stopping at iteration 2674 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = 0
# Early stopping at iteration 2618 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = 1
# Early stopping at iteration 2674 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = 2
# Early stopping at iteration 2791 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = 3
# Early stopping at iteration 2914 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = 4
# Early stopping at iteration 3021 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = 5
# Early stopping at iteration 3113 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = -5
# Early stopping at iteration 282 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = -4
# Early stopping at iteration 271 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = -3
# Early stopping at iteration 258 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = -2
# Early stopping at iteration 2914 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = -1
# Early stopping at iteration 2847 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = 0
# Early stopping at iteration 2820 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = 1
# Early stopping at iteration 2847 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = 2
# Early stopping at iteration 2914 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = 3
# Early stopping at iteration 258 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = 4
# Early stopping at iteration 271 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = 5
# Early stopping at iteration 282 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = -5
# Early stopping at iteration 292 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = -4
# Early stopping at iteration 280 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = -3
# Early stopping at iteration 271 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = -2
# Early stopping at iteration 3021 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = -1
# Early stopping at iteration 2979 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = 0
# Early stopping at iteration 2964 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = 1
# Early stopping at iteration 2979 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = 2
# Early stopping at iteration 3021 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = 3
# Early stopping at iteration 271 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = 4
# Early stopping at iteration 280 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = 5
# Early stopping at iteration 292 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = -5
# Early stopping at iteration 308 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = -4
# Early stopping at iteration 292 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = -3
# Early stopping at iteration 282 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = -2
# Early stopping at iteration 3113 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = -1
# Early stopping at iteration 3085 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = 0
# Early stopping at iteration 3076 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = 1
# Early stopping at iteration 3085 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = 2
# Early stopping at iteration 3113 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = 3
# Early stopping at iteration 282 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = 4
# Early stopping at iteration 292 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = 5
# Early stopping at iteration 308 (loss change < 1e-06 for 200 consecutive steps)

# %% [markdown]
# ##### store result for proposed method

# %%
c = 0


df_proposed = pd.DataFrame(columns =["X_start",  "y_start", "X_new", "y_new"])

for i in list(range(-5, 6, 1)):
    for j in list(range(-5, 6, 1)):

        print(f"currently running for x = {i} and y = {j}")
        x0 = np.array([i*1.0, j*1.0])
        X_new, y_new, history_proposed = obj.optimize_function(f=f, model = model, x0=x0, learning_rate=lr, max_iters=max_iters, tol=1e-6, patience =200)
        df_proposed.loc[c, ["X_new", "y_new"]] = X_new, y_new
        df_proposed.loc[c, "y_start"] = f(x0)
        df_proposed.loc[c, "X_start"] = x0

        c = c + 1

        X_new, y_new, x0 =  [None] * 3

    #     break
    # break
# Out:
# currently running for x = -5 and y = -5
# Early stopping at iteration 3206 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = -4
# Early stopping at iteration 3144 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = -3
# Early stopping at iteration 3078 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = -2
# Early stopping at iteration 3036 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = -1
# Early stopping at iteration 3034 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = 0
# Early stopping at iteration 3055 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = 1
# Early stopping at iteration 3093 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = 2
# Early stopping at iteration 3148 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = 3
# Early stopping at iteration 3306 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = 4
# Early stopping at iteration 3490 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -5 and y = 5
# Early stopping at iteration 3659 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = -5
# Early stopping at iteration 3131 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = -4
# Early stopping at iteration 3063 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = -3
# Early stopping at iteration 2991 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = -2
# Early stopping at iteration 2932 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = -1
# Early stopping at iteration 2921 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = 0
# Early stopping at iteration 2943 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = 1
# Early stopping at iteration 2992 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = 2
# Early stopping at iteration 3065 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = 3
# Early stopping at iteration 3221 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = 4
# Early stopping at iteration 3382 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -4 and y = 5
# Early stopping at iteration 3511 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = -5
# Early stopping at iteration 3042 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = -4
# Early stopping at iteration 2970 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = -3
# Early stopping at iteration 2887 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = -2
# Early stopping at iteration 2810 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = -1
# Early stopping at iteration 2776 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = 0
# Early stopping at iteration 2798 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = 1
# Early stopping at iteration 2869 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = 2
# Early stopping at iteration 2968 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = 3
# Early stopping at iteration 3114 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = 4
# Early stopping at iteration 3242 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -3 and y = 5
# Early stopping at iteration 3338 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = -5
# Early stopping at iteration 2957 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = -4
# Early stopping at iteration 2868 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = -3
# Early stopping at iteration 2770 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = -2
# Early stopping at iteration 2663 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = -1
# Early stopping at iteration 2583 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = 0
# Early stopping at iteration 2593 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = 1
# Early stopping at iteration 2711 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = 2
# Early stopping at iteration 2857 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = 3
# Early stopping at iteration 3000 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = 4
# Early stopping at iteration 3114 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -2 and y = 5
# Early stopping at iteration 3210 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = -5
# Early stopping at iteration 2928 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = -4
# Early stopping at iteration 2821 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = -3
# Early stopping at iteration 2688 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = -2
# Early stopping at iteration 2518 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = -1
# Early stopping at iteration 2317 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = 0
# Early stopping at iteration 2247 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = 1
# Early stopping at iteration 2511 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = 2
# Early stopping at iteration 2764 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = 3
# Early stopping at iteration 2943 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = 4
# Early stopping at iteration 3078 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = -1 and y = 5
# Early stopping at iteration 3185 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = -5
# Early stopping at iteration 2924 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = -4
# Early stopping at iteration 2812 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = -3
# Early stopping at iteration 2668 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = -2
# Early stopping at iteration 2464 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = -1
# Early stopping at iteration 2119 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = 0
# Early stopping at iteration 200 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = 1
# Early stopping at iteration 2370 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = 2
# Early stopping at iteration 2719 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = 3
# Early stopping at iteration 2922 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = 4
# Early stopping at iteration 3066 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 0 and y = 5
# Early stopping at iteration 3177 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = -5
# Early stopping at iteration 2944 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = -4
# Early stopping at iteration 2840 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = -3
# Early stopping at iteration 2713 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = -2
# Early stopping at iteration 2549 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = -1
# Early stopping at iteration 2350 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = 0
# Early stopping at iteration 2270 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = 1
# Early stopping at iteration 2525 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = 2
# Early stopping at iteration 2766 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = 3
# Early stopping at iteration 2945 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = 4
# Early stopping at iteration 3079 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 1 and y = 5
# Early stopping at iteration 3186 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = -5
# Early stopping at iteration 2987 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = -4
# Early stopping at iteration 2901 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = -3
# Early stopping at iteration 2804 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = -2
# Early stopping at iteration 2697 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = -1
# Early stopping at iteration 2619 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = 0
# Early stopping at iteration 2617 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = 1
# Early stopping at iteration 2729 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = 2
# Early stopping at iteration 2870 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = 3
# Early stopping at iteration 3004 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = 4
# Early stopping at iteration 3116 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 2 and y = 5
# Early stopping at iteration 3210 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = -5
# Early stopping at iteration 3083 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = -4
# Early stopping at iteration 3014 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = -3
# Early stopping at iteration 2928 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = -2
# Early stopping at iteration 2845 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = -1
# Early stopping at iteration 2810 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = 0
# Early stopping at iteration 2820 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = 1
# Early stopping at iteration 2886 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = 2
# Early stopping at iteration 2985 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = 3
# Early stopping at iteration 3112 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = 4
# Early stopping at iteration 3223 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 3 and y = 5
# Early stopping at iteration 3303 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = -5
# Early stopping at iteration 3201 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = -4
# Early stopping at iteration 3126 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = -3
# Early stopping at iteration 3037 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = -2
# Early stopping at iteration 2969 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = -1
# Early stopping at iteration 2952 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = 0
# Early stopping at iteration 2964 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = 1
# Early stopping at iteration 3009 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = 2
# Early stopping at iteration 3082 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = 3
# Early stopping at iteration 3207 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = 4
# Early stopping at iteration 3334 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 4 and y = 5
# Early stopping at iteration 3440 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = -5
# Early stopping at iteration 3296 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = -4
# Early stopping at iteration 3215 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = -3
# Early stopping at iteration 3125 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = -2
# Early stopping at iteration 3071 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = -1
# Early stopping at iteration 3064 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = 0
# Early stopping at iteration 3076 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = 1
# Early stopping at iteration 3110 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = 2
# Early stopping at iteration 3165 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = 3
# Early stopping at iteration 3286 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = 4
# Early stopping at iteration 3417 (loss change < 1e-06 for 200 consecutive steps)
# currently running for x = 5 and y = 5
# Early stopping at iteration 3538 (loss change < 1e-06 for 200 consecutive steps)

# %% [markdown]
# ##### Store result for autograd

# %%
c = 0

df_autograd = pd.DataFrame(columns =["X_start",  "y_start", "X_autograd", "y_autograd"])

for i in list(range(-5, 6, 1)):

    for j in list(range(-5, 6, 1)):

        print(f"currently running for x = {i} and y = {j}")
        x0 = np.array([i*1.0, j*1.0])

        x_torch, history_autograd = torch_optimization(args=x0, lr = lr, num_steps=max_iters, f=parabolic_loss_with_dips_3D_torch, patience =200, tol=1e-6)

        df_autograd.loc[c, "y_start"] = f(x0)
        df_autograd.loc[c, "X_start"] = x0

        df_autograd.loc[c, "X_autograd"] = x_torch
        df_autograd.loc[c, "y_autograd"] = f(x_torch)

        x_torch, x0 = [None] *2


        c = c + 1
# Out:
# currently running for x = -5 and y = -5
# Early stopping at step 837 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -5 and y = -4
# Early stopping at step 991 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -5 and y = -3
# Early stopping at step 720 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -5 and y = -2
# Early stopping at step 8595 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -5 and y = -1
# Early stopping at step 8596 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -5 and y = 0
# Early stopping at step 8596 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -5 and y = 1
# Early stopping at step 8596 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -5 and y = 2
# Early stopping at step 8595 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -5 and y = 3
# Early stopping at step 720 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -5 and y = 4
# Early stopping at step 995 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -5 and y = 5
# Early stopping at step 837 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -4 and y = -5
# Early stopping at step 991 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -4 and y = -4
# Early stopping at step 570 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -4 and y = -3
# Early stopping at step 760 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -4 and y = -2
# Early stopping at step 7290 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -4 and y = -1
# Early stopping at step 7291 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -4 and y = 0
# Early stopping at step 7291 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -4 and y = 1
# Early stopping at step 7291 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -4 and y = 2
# Early stopping at step 7290 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -4 and y = 3
# Early stopping at step 760 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -4 and y = 4
# Early stopping at step 553 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -4 and y = 5
# Early stopping at step 991 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -3 and y = -5
# Early stopping at step 839 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -3 and y = -4
# Early stopping at step 524 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -3 and y = -3
# Early stopping at step 422 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -3 and y = -2
# Early stopping at step 5872 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -3 and y = -1
# Early stopping at step 5874 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -3 and y = 0
# Early stopping at step 5874 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -3 and y = 1
# Early stopping at step 5874 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -3 and y = 2
# Early stopping at step 5872 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -3 and y = 3
# Early stopping at step 421 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -3 and y = 4
# Early stopping at step 524 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -3 and y = 5
# Early stopping at step 839 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -2 and y = -5
# Early stopping at step 8595 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -2 and y = -4
# Early stopping at step 7290 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -2 and y = -3
# Early stopping at step 5872 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -2 and y = -2
# Early stopping at step 4401 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -2 and y = -1
# Early stopping at step 4271 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -2 and y = 0
# Early stopping at step 4271 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -2 and y = 1
# Early stopping at step 4271 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -2 and y = 2
# Early stopping at step 4401 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -2 and y = 3
# Early stopping at step 5872 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -2 and y = 4
# Early stopping at step 7290 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -2 and y = 5
# Early stopping at step 8595 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -1 and y = -5
# Early stopping at step 8596 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -1 and y = -4
# Early stopping at step 7291 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -1 and y = -3
# Early stopping at step 5874 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -1 and y = -2
# Early stopping at step 4271 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -1 and y = -1
# Early stopping at step 2461 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -1 and y = 0
# Early stopping at step 2363 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -1 and y = 1
# Early stopping at step 2461 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -1 and y = 2
# Early stopping at step 4271 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -1 and y = 3
# Early stopping at step 5874 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -1 and y = 4
# Early stopping at step 7291 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = -1 and y = 5
# Early stopping at step 8596 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 0 and y = -5
# Early stopping at step 8596 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 0 and y = -4
# Early stopping at step 7291 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 0 and y = -3
# Early stopping at step 5874 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 0 and y = -2
# Early stopping at step 4271 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 0 and y = -1
# Early stopping at step 2363 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 0 and y = 0
# Early stopping at step 200 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 0 and y = 1
# Early stopping at step 2363 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 0 and y = 2
# Early stopping at step 4271 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 0 and y = 3
# Early stopping at step 5874 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 0 and y = 4
# Early stopping at step 7291 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 0 and y = 5
# Early stopping at step 8596 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 1 and y = -5
# Early stopping at step 8596 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 1 and y = -4
# Early stopping at step 7291 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 1 and y = -3
# Early stopping at step 5874 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 1 and y = -2
# Early stopping at step 4271 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 1 and y = -1
# Early stopping at step 2461 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 1 and y = 0
# Early stopping at step 2363 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 1 and y = 1
# Early stopping at step 2461 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 1 and y = 2
# Early stopping at step 4271 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 1 and y = 3
# Early stopping at step 5874 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 1 and y = 4
# Early stopping at step 7291 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 1 and y = 5
# Early stopping at step 8596 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 2 and y = -5
# Early stopping at step 8595 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 2 and y = -4
# Early stopping at step 7290 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 2 and y = -3
# Early stopping at step 5872 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 2 and y = -2
# Early stopping at step 4401 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 2 and y = -1
# Early stopping at step 4271 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 2 and y = 0
# Early stopping at step 4271 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 2 and y = 1
# Early stopping at step 4271 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 2 and y = 2
# Early stopping at step 4401 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 2 and y = 3
# Early stopping at step 5872 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 2 and y = 4
# Early stopping at step 7290 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 2 and y = 5
# Early stopping at step 8595 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 3 and y = -5
# Early stopping at step 720 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 3 and y = -4
# Early stopping at step 760 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 3 and y = -3
# Early stopping at step 421 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 3 and y = -2
# Early stopping at step 5872 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 3 and y = -1
# Early stopping at step 5874 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 3 and y = 0
# Early stopping at step 5873 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 3 and y = 1
# Early stopping at step 5874 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 3 and y = 2
# Early stopping at step 5872 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 3 and y = 3
# Early stopping at step 421 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 3 and y = 4
# Early stopping at step 763 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 3 and y = 5
# Early stopping at step 844 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 4 and y = -5
# Early stopping at step 1666 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 4 and y = -4
# Early stopping at step 550 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 4 and y = -3
# Early stopping at step 524 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 4 and y = -2
# Early stopping at step 7290 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 4 and y = -1
# Early stopping at step 7291 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 4 and y = 0
# Early stopping at step 7291 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 4 and y = 1
# Early stopping at step 7291 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 4 and y = 2
# Early stopping at step 7290 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 4 and y = 3
# Early stopping at step 760 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 4 and y = 4
# Early stopping at step 550 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 4 and y = 5
# Early stopping at step 991 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 5 and y = -5
# Early stopping at step 837 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 5 and y = -4
# Early stopping at step 991 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 5 and y = -3
# Early stopping at step 839 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 5 and y = -2
# Early stopping at step 8595 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 5 and y = -1
# Early stopping at step 8596 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 5 and y = 0
# Early stopping at step 8596 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 5 and y = 1
# Early stopping at step 8596 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 5 and y = 2
# Early stopping at step 8595 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 5 and y = 3
# Early stopping at step 719 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 5 and y = 4
# Early stopping at step 1673 (loss change < 1e-06 for 200 consecutive epochs)
# currently running for x = 5 and y = 5
# Early stopping at step 837 (loss change < 1e-06 for 200 consecutive epochs)

# %% [markdown]
# ##### Genetic algorithm

# %%
import pygad

c = 0

df_ga = pd.DataFrame(columns =["X_start",  "y_start", "X_ga", "y_ga"])

for i in list(range(-5, 6, 1)):

    for j in list(range(-5, 6, 1)):

        print(f"currently running for x = {i} and y = {j}")
        x0 = np.array([i*1.0, j*1.0])

        initial_population = np.array([
            x0 + np.random.uniform(-0.5, 0.5, size=2) for _ in range(10)
        ])

        ga_instance = pygad.GA(
            initial_population=initial_population,
            num_generations=50,
            num_parents_mating=5,
            fitness_func=fitness_func,
            mutation_type="random",
            mutation_num_genes=1,         
            crossover_type="single_point", 
            keep_parents=2,                
            stop_criteria=["saturate_10"]  
        )

        ga_instance.run()

        solution, solution_fitness, _ = ga_instance.best_solution()
        best_value = -solution_fitness


        df_ga.loc[c, "y_start"] = f(x0)
        df_ga.loc[c, "X_start"] = x0

        df_ga.loc[c, "X_ga"] = solution
        df_ga.loc[c, "y_ga"] = best_value
        solution, x0 = [None] *2


        c = c + 1
# Out:
# currently running for x = -5 and y = -5
# currently running for x = -5 and y = -4
# currently running for x = -5 and y = -3
# currently running for x = -5 and y = -2
# currently running for x = -5 and y = -1
# currently running for x = -5 and y = 0
# currently running for x = -5 and y = 1
# currently running for x = -5 and y = 2
# currently running for x = -5 and y = 3
# currently running for x = -5 and y = 4
# currently running for x = -5 and y = 5
# currently running for x = -4 and y = -5
# currently running for x = -4 and y = -4
# currently running for x = -4 and y = -3
# currently running for x = -4 and y = -2
# currently running for x = -4 and y = -1
# currently running for x = -4 and y = 0
# currently running for x = -4 and y = 1
# currently running for x = -4 and y = 2
# currently running for x = -4 and y = 3
# currently running for x = -4 and y = 4
# currently running for x = -4 and y = 5
# currently running for x = -3 and y = -5
# currently running for x = -3 and y = -4
# currently running for x = -3 and y = -3
# currently running for x = -3 and y = -2
# currently running for x = -3 and y = -1
# currently running for x = -3 and y = 0
# currently running for x = -3 and y = 1
# currently running for x = -3 and y = 2
# currently running for x = -3 and y = 3
# currently running for x = -3 and y = 4
# currently running for x = -3 and y = 5
# currently running for x = -2 and y = -5
# currently running for x = -2 and y = -4
# currently running for x = -2 and y = -3
# currently running for x = -2 and y = -2
# currently running for x = -2 and y = -1
# currently running for x = -2 and y = 0
# currently running for x = -2 and y = 1
# currently running for x = -2 and y = 2
# currently running for x = -2 and y = 3
# currently running for x = -2 and y = 4
# currently running for x = -2 and y = 5
# currently running for x = -1 and y = -5
# currently running for x = -1 and y = -4
# currently running for x = -1 and y = -3
# currently running for x = -1 and y = -2
# currently running for x = -1 and y = -1
# currently running for x = -1 and y = 0
# currently running for x = -1 and y = 1
# currently running for x = -1 and y = 2
# currently running for x = -1 and y = 3
# currently running for x = -1 and y = 4
# currently running for x = -1 and y = 5
# currently running for x = 0 and y = -5
# currently running for x = 0 and y = -4
# currently running for x = 0 and y = -3
# currently running for x = 0 and y = -2
# currently running for x = 0 and y = -1
# currently running for x = 0 and y = 0
# currently running for x = 0 and y = 1
# currently running for x = 0 and y = 2
# currently running for x = 0 and y = 3
# currently running for x = 0 and y = 4
# currently running for x = 0 and y = 5
# currently running for x = 1 and y = -5
# currently running for x = 1 and y = -4
# currently running for x = 1 and y = -3
# currently running for x = 1 and y = -2
# currently running for x = 1 and y = -1
# currently running for x = 1 and y = 0
# currently running for x = 1 and y = 1
# currently running for x = 1 and y = 2
# currently running for x = 1 and y = 3
# currently running for x = 1 and y = 4
# currently running for x = 1 and y = 5
# currently running for x = 2 and y = -5
# currently running for x = 2 and y = -4
# currently running for x = 2 and y = -3
# currently running for x = 2 and y = -2
# currently running for x = 2 and y = -1
# currently running for x = 2 and y = 0
# currently running for x = 2 and y = 1
# currently running for x = 2 and y = 2
# currently running for x = 2 and y = 3
# currently running for x = 2 and y = 4
# currently running for x = 2 and y = 5
# currently running for x = 3 and y = -5
# currently running for x = 3 and y = -4
# currently running for x = 3 and y = -3
# currently running for x = 3 and y = -2
# currently running for x = 3 and y = -1
# currently running for x = 3 and y = 0
# currently running for x = 3 and y = 1
# currently running for x = 3 and y = 2
# currently running for x = 3 and y = 3
# currently running for x = 3 and y = 4
# currently running for x = 3 and y = 5
# currently running for x = 4 and y = -5
# currently running for x = 4 and y = -4
# currently running for x = 4 and y = -3
# currently running for x = 4 and y = -2
# currently running for x = 4 and y = -1
# currently running for x = 4 and y = 0
# currently running for x = 4 and y = 1
# currently running for x = 4 and y = 2
# currently running for x = 4 and y = 3
# currently running for x = 4 and y = 4
# currently running for x = 4 and y = 5
# currently running for x = 5 and y = -5
# currently running for x = 5 and y = -4
# currently running for x = 5 and y = -3
# currently running for x = 5 and y = -2
# currently running for x = 5 and y = -1
# currently running for x = 5 and y = 0
# currently running for x = 5 and y = 1
# currently running for x = 5 and y = 2
# currently running for x = 5 and y = 3
# currently running for x = 5 and y = 4
# currently running for x = 5 and y = 5

# %%
df_ga
# Out:
#        X_start    y_start                                            X_ga  \
# 0    [-5. -5.]  39.864787   [-0.022991450843430128, 0.004425203169984293]
# 1    [-5. -4.]  30.796954   [-0.04450301154256042, -0.006023989307250899]
# 2    [-5. -3.]  23.864787   [0.020478074224639098, -0.009879646451778967]
# 3    [-5. -2.]  28.932167   [-0.06152145801179776, 0.0034087436061513987]
# 4    [-5. -1.]  26.000000    [-0.036971262233572944, 0.10831058753729939]
# ..         ...        ...                                             ...
# 116    [5. 1.]  26.000000   [-0.0009549135674202791, 0.01785265781318135]
# 117    [5. 2.]  28.932167   [-0.019201566281614957, -0.09874168312600418]
# 118    [5. 3.]  23.864787    [-0.016922726157472034, 0.04080139176926045]
# 119    [5. 4.]  30.796954  [-0.019966663734600543, -0.023664296792335504]
# 120    [5. 5.]  39.864787     [-0.0316319880969782, 0.027763704743782647]
#
#          y_ga
# 0    0.000548
# 1    0.002017
# 2    0.000517
# 3    0.003797
# 4    0.013098
# ..        ...
# 116   0.00032
# 117  0.010119
# 118  0.001951
# 119  0.000959
# 120  0.001771
#
# [121 rows x 4 columns]

# %%
df_autograd["y_start"] = df_autograd["y_start"].apply(pd.to_numeric, errors='coerce')
df_autograd["X_start"] = df_autograd["X_start"].astype(str)

df_proposed["y_start"] = df_proposed["y_start"].apply(pd.to_numeric, errors='coerce')
df_proposed["X_start"] = df_proposed["X_start"].astype(str)

df_cd["y_start"] = df_cd["y_start"].apply(pd.to_numeric, errors='coerce')
df_cd["X_start"] = df_cd["X_start"].astype(str)

df_ga["y_start"] = df_ga["y_start"].apply(pd.to_numeric, errors='coerce')
df_ga["X_start"] = df_ga["X_start"].astype(str)

df = pd.merge(df_autograd, df_proposed).merge(df_cd).merge(df_ga)
df["y_autograd"] = df["y_autograd"].apply(pd.to_numeric, errors='coerce')
df["y_gd_cd"] = df["y_gd_cd"].apply(pd.to_numeric, errors='coerce')
df["y_ga"] = df["y_ga"].apply(pd.to_numeric, errors='coerce')

# %%
df
# Out:
#        X_start    y_start                                        X_autograd  \
# 0    [-5. -5.]  39.864787          [-4.862649440765381, -4.862649440765381]
# 1    [-5. -4.]  30.796954         [-4.868879318237305, -3.8987724781036377]
# 2    [-5. -3.]  23.864787          [-4.871456623077393, -2.940467357635498]
# 3    [-5. -2.]  28.932167  [-0.008045969530940056, -3.2319688673598665e-30]
# 4    [-5. -1.]  26.000000    [-0.008038141764700413, 2.312142466135948e-43]
# ..         ...        ...                                               ...
# 116    [5. 1.]  26.000000    [0.008038141764700413, -2.312142466135948e-43]
# 117    [5. 2.]  28.932167    [0.008045969530940056, 3.2319688673598665e-30]
# 118    [5. 3.]  23.864787            [4.871456623077393, 2.940467357635498]
# 119    [5. 4.]  30.796954           [4.868876934051514, 3.8987715244293213]
# 120    [5. 5.]  39.864787            [4.862649440765381, 4.862649440765381]
#
#      y_autograd                                           X_new     y_new  \
# 0     38.563417  [-0.00853792010457255, 0.00017481146642239764]  0.000073
# 1     29.782902   [-0.00894265879469458, 0.0007858209573896602]  0.000081
# 2     23.077296   [-0.009598668921171338, 0.002103588078171015]  0.000097
# 3      0.000065   [-0.010353488458349602, 0.004575689935336413]  0.000128
# 4      0.000065    [-0.01051090953660605, 0.006882276857140823]  0.000158
# ..          ...                                             ...       ...
# 116    0.000065     [0.01020314604829764, 0.011440757795071477]  0.000235
# 117    0.000065     [0.00916190873249434, 0.013038678011525917]  0.000254
# 118   23.077296    [0.007653456615116738, 0.014601192495319992]  0.000272
# 119   29.782902     [0.006904238518472994, 0.01518395324364974]  0.000278
# 120   38.563417    [0.006514291936582595, 0.015456732233360526]  0.000281
#
#                                             X_gd_cd    y_gd_cd  \
# 0          [-4.862640965381999, -4.862640965381999]  38.563417
# 1         [-4.868872605201631, -3.8987697114644746]  29.782902
# 2         [-4.871450591439981, -2.9404660720442095]  23.077296
# 3    [-0.009827616704259492, -0.003964511626513429]   0.000112
# 4    [-0.01039177837310584, -0.0020783556951195973]   0.000112
# ..                                              ...        ...
# 116    [0.01039177837310584, 0.0020783556951195973]   0.000112
# 117   [0.009827616704263183, 0.0039645116265140815]   0.000112
# 118         [4.871450591440869, 2.9404660720450977]  23.077296
# 119         [4.868872605200565, 3.8987697114644746]  29.782902
# 120          [4.862640965382354, 4.862640965382354]  38.563417
#
#                                                X_ga      y_ga
# 0     [-0.022991450843430128, 0.004425203169984293]  0.000548
# 1     [-0.04450301154256042, -0.006023989307250899]  0.002017
# 2     [0.020478074224639098, -0.009879646451778967]  0.000517
# 3     [-0.06152145801179776, 0.0034087436061513987]  0.003797
# 4      [-0.036971262233572944, 0.10831058753729939]  0.013098
# ..                                              ...       ...
# 116   [-0.0009549135674202791, 0.01785265781318135]  0.000320
# 117   [-0.019201566281614957, -0.09874168312600418]  0.010119
# 118    [-0.016922726157472034, 0.04080139176926045]  0.001951
# 119  [-0.019966663734600543, -0.023664296792335504]  0.000959
# 120     [-0.0316319880969782, 0.027763704743782647]  0.001771
#
# [121 rows x 10 columns]

# %% [markdown]
# ##### Convert the data to long format

# %%
long_df = pd.melt(
    df,
    id_vars=["X_start", "y_start"],               
    value_vars=["y_autograd", "y_new", "y_gd_cd", "y_ga"],  
    var_name="type",                                
    value_name="value"                             
)

long_df["X_start"] = long_df["X_start"].astype(str)

# %%
long_df
# Out:
#        X_start    y_start        type      value
# 0    [-5. -5.]  39.864787  y_autograd  38.563417
# 1    [-5. -4.]  30.796954  y_autograd  29.782902
# 2    [-5. -3.]  23.864787  y_autograd  23.077296
# 3    [-5. -2.]  28.932167  y_autograd   0.000065
# 4    [-5. -1.]  26.000000  y_autograd   0.000065
# ..         ...        ...         ...        ...
# 479    [5. 1.]  26.000000        y_ga    0.00032
# 480    [5. 2.]  28.932167        y_ga   0.010119
# 481    [5. 3.]  23.864787        y_ga   0.001951
# 482    [5. 4.]  30.796954        y_ga   0.000959
# 483    [5. 5.]  39.864787        y_ga   0.001771
#
# [484 rows x 4 columns]

# %% [markdown]
# ##### Plot of Suboptimality Gap across method

# %%
import seaborn as sns
fig, ax = plt.subplots(1,1, dpi = 300, figsize=(2.1,2.1))
ax = sns.boxplot(long_df, x = "type", y = "value",ax=ax, linewidth=0.5, flierprops=dict(marker='o', markeredgecolor='black'), width=0.4, fliersize=0.15, dodge=True, medianprops={"color": "black","linewidth":1})
ax.set_yscale("log")
ax = utility.custom_figure_axis(ax=ax, show_ticks = True, rotation =0, tick_fontsize = 4, label_fontsize = 4, legend_fontsize = 4)
ax.set_ylabel("Suboptimality Gap")
plt.tight_layout()
plt.savefig("simulated_2d_suboptimality.pdf", dpi = 300)

# %%
print("The mean Suboptimality gap with Autograd is ", df["y_autograd"].mean())
print("The mean Suboptimality gap with Gradient Descent is ", df["y_gd_cd"].mean())
print("The mean Suboptimality gap with genetic algorithm is ", df["y_ga"].mean())
print("The mean Suboptimality gap with PNGA is ", df["y_new"].mean())
print("The std of Suboptimality gap with Autograd is ", df["y_autograd"].std())
print("The std of Suboptimality gap with Gradient Descent is ", df["y_gd_cd"].std())
print("The std of Suboptimality gap with genetic algorithm is ", df["y_ga"].std())
print("The std of Suboptimality gap with PNGA is ", df["y_new"].std())
# Out:
# The mean Suboptimality gap with Autograd is  6.658029200358835
# The mean Suboptimality gap with Gradient Descent is  6.658067221118166
# The mean Suboptimality gap with genetic algorithm is  0.003255578952183489
# The mean Suboptimality gap with PNGA is  0.00017830301625193005
# The std of Suboptimality gap with Autograd is  11.388750036343422
# The std of Suboptimality gap with Gradient Descent is  11.388727623050565
# The std of Suboptimality gap with genetic algorithm is  0.004937923117150737
# The std of Suboptimality gap with PNGA is  9.781885861281708e-05

# %% [markdown]
# ##### Show result

# %%
# Load the saved model
model.save("simulated_2d.keras")
loaded_model = load_model("simulated_2d.keras") 
test_loss = loaded_model.evaluate(X_test, y_test)
print("Test loss:", loaded_model.evaluate(X_test, y_test))
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 2.0308
# 32/32 [==============================] - 0s 2ms/step - loss: 2.0308
# Test loss: 2.0308215618133545

# %% [markdown]
# #### pickle result

# %%
res = {"model": model, "history": history, "result": df}

# Save (pickle) the dictionary to a file
with open("simulated_2d.pkl", "wb") as file:
    pickle.dump(res, file)

# %%
# Load (unpickle) the dictionary from the file
with open("simulated_2d.pkl", "rb") as file:
    loaded_data = pickle.load(file)

# print(loaded_data)

# %% [markdown]
# ##### Test if pickled model is working

# %%
loaded_model1 = loaded_data["model"]
# test_loss = loaded_model.evaluate(X_test, y_test)
print("Test loss:", loaded_model1.evaluate(X_test, y_test))
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 2.0308
# Test loss: 2.0308215618133545

# %%
# df.to_csv("simulated_2d.csv", index=False)
