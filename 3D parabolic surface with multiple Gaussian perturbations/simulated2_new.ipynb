# %%
import sys
sys.path.append("../")

# %% [markdown]
# ##### import library

# %%
# Standard libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle

# 3D plotting
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits import mplot3d
from matplotlib.colors import Normalize, LinearSegmentedColormap

# Machine learning and preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons

# Deep learning (PyTorch and TensorFlow)
import torch
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, BatchNormalization, LeakyReLU
from tensorflow.keras.regularizers import l2

# Plotly for interactive visualization
import plotly.graph_objects as go

# Custom utility module
import utility
# Out:
# 2025-03-09 11:16:07.047058: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-09 11:16:07.096847: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-09 11:16:07.096890: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-09 11:16:07.098147: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-09 11:16:07.106077: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-09 11:16:07.992681: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ##### Define functions

# %%
def parabolic_loss_with_dips_3D(args):
    x, y = args
    base_parabola = x**2 + y**2
    
    dips = sum(
        10 * np.exp(-5 * ((x - i) ** 2 + (y - j) ** 2))
        for i in list(range(-5, -2)) + list(range(3, 6))  
        for j in list(range(-5, -2)) + list(range(3, 6))   
    )
    
    return base_parabola - dips


f = parabolic_loss_with_dips_3D

# %%
# Define the function in PyTorch
def parabolic_loss_with_dips_3D_torch(args):
    x, y = args
    base_parabola = x**2 + y**2

    dips = sum(
        10 * torch.exp(-5 * ((x - i) ** 2 + (y - j) ** 2))
        for i in list(range(-5, -2)) + list(range(3, 6))  
        for j in list(range(-5, -2)) + list(range(3, 6))   
    )

    return base_parabola - dips

# %% [markdown]
# ##### Define the function in PyTorch

# %% [markdown]
# ##### Plot graph

# %%
def plot_graph(fig, x, y, z):

    # 3D Surface Plot
    ax1 = fig.add_subplot(1, 2, 1, projection='3d')
    surf = ax1.plot_surface(x, y, z, cmap=cmap, edgecolor="none")
    ax1.set_title("3D Surface Plot", fontsize=10)
    ax1.set_xlabel("X-axis", fontsize=10)
    ax1.set_ylabel("Y-axis", fontsize=10)
    # ax1.set_zlabel("Function Value", fontsize=5)

    # Add colorbar for 3D plot
    cbar1 = fig.colorbar(surf, ax=ax1, fraction=0.046, pad=0.04)
    cbar1.set_label("Function Value", fontsize=10)

    # 2D Contour Plot
    ax2 = fig.add_subplot(1, 2, 2)
    contour = ax2.contourf(x, y, z, levels=50, cmap=cmap)
    ax2.set_xlabel("X-axis", fontsize=10)
    ax2.set_ylabel("Y-axis", fontsize=10)
    ax2.set_title("2D Contour Plot", fontsize=10)

    # Add colorbar for 2D plot without overlapping
    cbar2 = fig.colorbar(contour, ax=ax2, fraction=0.046, pad=0.04)
    cbar2.set_label("Function Value", fontsize=10)

    ax1.tick_params(axis='x', labelsize=10, rotation=0)
    ax1.tick_params(axis='y', labelsize=10)
    ax1.tick_params(axis='both', which='both', width=0.5)

    # Improve layout to avoid overlap
    plt.tight_layout()
    # plt.show()

    return fig, ax1, ax2

# %% [markdown]
# ##### Initialize class object and grid

# %%
obj = utility.CentralDifference()
# Create a grid of x and y values
interval = 1000
max_iters = 1000
min_grid = -5
max_grid = 5
x = np.linspace(min_grid, max_grid, interval)
y = np.linspace(min_grid, max_grid, interval)
x, y = np.meshgrid(x, y)
z = f((x, y))

# %% [markdown]
# ##### Define colormap

# %%
colors = [
    (0.0, "navy"),         # Deep blue for the minimum
    (0.01, "blue"),         # Blue
    (0.2, "cyan"),         # Cyan
    (0.4, "limegreen"),    # Green
    (0.6, "yellow"),       # Yellow
    (0.8, "orange"),       # Orange
    (1.0, "darkred"),      # Deep red for the maximum
]
cmap = LinearSegmentedColormap.from_list("improved_gradient_cmap", colors)

# %% [markdown]
# ##### Show 3D visualization and contourplot

# %%
fig = plt.figure(figsize=(12, 6), dpi=300)
fig, ax1, ax2 = plot_graph(fig, x, y, z)

ax1.set_ylabel("y-axis", labelpad=1)
ax1.set_xlabel("x-axis", labelpad=1)
ax1.set_title("3D surface plot", fontsize=10)
ax1 = utility.custom_figure_axis(ax=ax1, show_ticks = True, rotation =0, tick_fontsize = 10, label_fontsize = 10, legend_fontsize = 10)

ax2.set_ylabel("y-axis", labelpad=1)
ax2.set_xlabel("x-axis", labelpad=1)
ax2.set_title("2D contour plot", fontsize=10)
ax2 = utility.custom_figure_axis(ax=ax2, show_ticks = True, rotation =0, tick_fontsize = 10, label_fontsize = 10, legend_fontsize = 10)
ax1.grid()
plt.savefig("simulated2_loss.pdf", dpi = 300, transparent=False, bbox_inches="tight")

# %% [markdown]
# ##### SHow a dummy example

# %%
args = [-0.16210637, -0.11185439]

grad = obj.compute_gradient(args = args, f = f)
print("Gradient:", grad)
# Out:
# Gradient: [-0.32421274 -0.22370878]

# %% [markdown]
# ##### Define parametrs and variables

# %%
num_samples=5000
dimension=2
batch_size=512

# %% [markdown]
# ##### Generate synthetic data to model the gradient of function with min and max grid

# %%
X_train, X_test, y_train, y_test = obj.generate_random_data(f=f, num_samples=num_samples, dimension=dimension, value_range=(min_grid,max_grid))

# %% [markdown]
# ##### Define model architecture

# %%
model = Sequential([
    Dense(128, input_shape=(dimension,), activation='leaky_relu'),
    Dense(64, activation='leaky_relu'),
    Dense(32, activation='leaky_relu'),
    Dense(dimension)
])


model.compile(loss='mse', optimizer = tf.keras.optimizers.Adam(learning_rate=0.001))

epochs = 3000

history = model.fit(X_train, y_train, validation_split=0.2, epochs=epochs, batch_size=batch_size, verbose=1)
# Out:
# Epoch 1/3000
# 7/7 [==============================] - 1s 25ms/step - loss: 41.2494 - val_loss: 35.6314
# Epoch 2/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 33.8458 - val_loss: 29.9103
# Epoch 3/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 28.2872 - val_loss: 26.2218
# Epoch 4/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 24.6065 - val_loss: 24.0229
# Epoch 5/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 22.2563 - val_loss: 22.4409
# Epoch 6/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 20.8099 - val_loss: 21.4547
# Epoch 7/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 20.2345 - val_loss: 21.1489
# Epoch 8/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 20.1240 - val_loss: 20.8646
# Epoch 9/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.9357 - val_loss: 20.6210
# Epoch 10/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.7917 - val_loss: 20.5430
# Epoch 11/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.7124 - val_loss: 20.4859
# Epoch 12/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.6471 - val_loss: 20.4786
# Epoch 13/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.5900 - val_loss: 20.4945
# Epoch 14/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.6011 - val_loss: 20.5220
# Epoch 15/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.5155 - val_loss: 20.5428
# Epoch 16/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.5367 - val_loss: 20.5310
# Epoch 17/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.5005 - val_loss: 20.5099
# Epoch 18/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.4996 - val_loss: 20.4147
# Epoch 19/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.4661 - val_loss: 20.3521
# Epoch 20/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.4793 - val_loss: 20.3592
# Epoch 21/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.4280 - val_loss: 20.3684
# Epoch 22/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.4354 - val_loss: 20.4036
# Epoch 23/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.4274 - val_loss: 20.3820
# Epoch 24/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.4108 - val_loss: 20.3035
# Epoch 25/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.4130 - val_loss: 20.2973
# Epoch 26/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.4140 - val_loss: 20.3330
# Epoch 27/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.3790 - val_loss: 20.3543
# Epoch 28/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.3743 - val_loss: 20.2889
# Epoch 29/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.4097 - val_loss: 20.3963
# Epoch 30/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.3780 - val_loss: 20.3549
# Epoch 31/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.3614 - val_loss: 20.2963
# Epoch 32/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.3505 - val_loss: 20.3397
# Epoch 33/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.3646 - val_loss: 20.4781
# Epoch 34/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.3696 - val_loss: 20.3262
# Epoch 35/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.3550 - val_loss: 20.3018
# Epoch 36/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.3244 - val_loss: 20.2699
# Epoch 37/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.3195 - val_loss: 20.2912
# Epoch 38/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.3253 - val_loss: 20.3107
# Epoch 39/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.3362 - val_loss: 20.2913
# Epoch 40/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.3520 - val_loss: 20.4048
# Epoch 41/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.3400 - val_loss: 20.2414
# Epoch 42/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.3061 - val_loss: 20.2859
# Epoch 43/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.3145 - val_loss: 20.3087
# Epoch 44/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.3020 - val_loss: 20.3561
# Epoch 45/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.3110 - val_loss: 20.3297
# Epoch 46/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2965 - val_loss: 20.2811
# Epoch 47/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.3302 - val_loss: 20.2667
# Epoch 48/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.2888 - val_loss: 20.2547
# Epoch 49/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2926 - val_loss: 20.3275
# Epoch 50/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.3294 - val_loss: 20.2879
# Epoch 51/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.3087 - val_loss: 20.2984
# Epoch 52/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.3187 - val_loss: 20.2823
# Epoch 53/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2879 - val_loss: 20.2515
# Epoch 54/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2875 - val_loss: 20.2568
# Epoch 55/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.3099 - val_loss: 20.2103
# Epoch 56/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.3265 - val_loss: 20.2773
# Epoch 57/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2800 - val_loss: 20.2283
# Epoch 58/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2913 - val_loss: 20.2815
# Epoch 59/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2775 - val_loss: 20.3195
# Epoch 60/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.2871 - val_loss: 20.2682
# Epoch 61/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.3204 - val_loss: 20.2581
# Epoch 62/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2548 - val_loss: 20.3842
# Epoch 63/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.3149 - val_loss: 20.3047
# Epoch 64/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2635 - val_loss: 20.2273
# Epoch 65/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2777 - val_loss: 20.3276
# Epoch 66/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2553 - val_loss: 20.2889
# Epoch 67/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.2690 - val_loss: 20.2784
# Epoch 68/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2711 - val_loss: 20.3620
# Epoch 69/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2786 - val_loss: 20.3220
# Epoch 70/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2568 - val_loss: 20.2885
# Epoch 71/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2518 - val_loss: 20.2722
# Epoch 72/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2420 - val_loss: 20.2703
# Epoch 73/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.2683 - val_loss: 20.3067
# Epoch 74/3000
# 7/7 [==============================] - 0s 15ms/step - loss: 19.2557 - val_loss: 20.3781
# Epoch 75/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2717 - val_loss: 20.2738
# Epoch 76/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2477 - val_loss: 20.3411
# Epoch 77/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2845 - val_loss: 20.2736
# Epoch 78/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.2444 - val_loss: 20.2416
# Epoch 79/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2785 - val_loss: 20.2932
# Epoch 80/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.3256 - val_loss: 20.3432
# Epoch 81/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.2437 - val_loss: 20.3307
# Epoch 82/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2349 - val_loss: 20.3186
# Epoch 83/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2500 - val_loss: 20.2669
# Epoch 84/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2742 - val_loss: 20.3025
# Epoch 85/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.2449 - val_loss: 20.2714
# Epoch 86/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2617 - val_loss: 20.2370
# Epoch 87/3000
# 7/7 [==============================] - 0s 15ms/step - loss: 19.2303 - val_loss: 20.2831
# Epoch 88/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.2452 - val_loss: 20.2366
# Epoch 89/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.2277 - val_loss: 20.2844
# Epoch 90/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2323 - val_loss: 20.3545
# Epoch 91/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.2701 - val_loss: 20.3089
# Epoch 92/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2812 - val_loss: 20.2934
# Epoch 93/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.2538 - val_loss: 20.3272
# Epoch 94/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2414 - val_loss: 20.2559
# Epoch 95/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.2578 - val_loss: 20.2557
# Epoch 96/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2053 - val_loss: 20.3378
# Epoch 97/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2425 - val_loss: 20.2685
# Epoch 98/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2485 - val_loss: 20.2614
# Epoch 99/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2126 - val_loss: 20.3391
# Epoch 100/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.2716 - val_loss: 20.3715
# Epoch 101/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2368 - val_loss: 20.2640
# Epoch 102/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2900 - val_loss: 20.2834
# Epoch 103/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2404 - val_loss: 20.3683
# Epoch 104/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.2267 - val_loss: 20.3058
# Epoch 105/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2033 - val_loss: 20.3021
# Epoch 106/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2305 - val_loss: 20.2427
# Epoch 107/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2049 - val_loss: 20.2415
# Epoch 108/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2115 - val_loss: 20.2133
# Epoch 109/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2152 - val_loss: 20.2837
# Epoch 110/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.2232 - val_loss: 20.3045
# Epoch 111/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2325 - val_loss: 20.2929
# Epoch 112/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.1984 - val_loss: 20.2888
# Epoch 113/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2158 - val_loss: 20.2496
# Epoch 114/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2659 - val_loss: 20.3158
# Epoch 115/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2328 - val_loss: 20.2481
# Epoch 116/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2431 - val_loss: 20.2225
# Epoch 117/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2238 - val_loss: 20.3262
# Epoch 118/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.2535 - val_loss: 20.3576
# Epoch 119/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2136 - val_loss: 20.2419
# Epoch 120/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2533 - val_loss: 20.1996
# Epoch 121/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2243 - val_loss: 20.2813
# Epoch 122/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2086 - val_loss: 20.3010
# Epoch 123/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2109 - val_loss: 20.3201
# Epoch 124/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.1960 - val_loss: 20.3377
# Epoch 125/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2304 - val_loss: 20.3144
# Epoch 126/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.2126 - val_loss: 20.3033
# Epoch 127/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.2322 - val_loss: 20.3272
# Epoch 128/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2272 - val_loss: 20.2731
# Epoch 129/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.2373 - val_loss: 20.2711
# Epoch 130/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2139 - val_loss: 20.3188
# Epoch 131/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.1733 - val_loss: 20.2852
# Epoch 132/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2047 - val_loss: 20.2575
# Epoch 133/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.1734 - val_loss: 20.3271
# Epoch 134/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2272 - val_loss: 20.3360
# Epoch 135/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2015 - val_loss: 20.2661
# Epoch 136/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2196 - val_loss: 20.2978
# Epoch 137/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2268 - val_loss: 20.2493
# Epoch 138/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.2223 - val_loss: 20.3210
# Epoch 139/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2031 - val_loss: 20.3322
# Epoch 140/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.1830 - val_loss: 20.2896
# Epoch 141/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.1685 - val_loss: 20.2661
# Epoch 142/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.1979 - val_loss: 20.1974
# Epoch 143/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2150 - val_loss: 20.2649
# Epoch 144/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.2726 - val_loss: 20.3604
# Epoch 145/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.1504 - val_loss: 20.2774
# Epoch 146/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2839 - val_loss: 20.2145
# Epoch 147/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2403 - val_loss: 20.4233
# Epoch 148/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2105 - val_loss: 20.3140
# Epoch 149/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.2084 - val_loss: 20.2035
# Epoch 150/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.1879 - val_loss: 20.3263
# Epoch 151/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2389 - val_loss: 20.2722
# Epoch 152/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.1983 - val_loss: 20.2583
# Epoch 153/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.1876 - val_loss: 20.2438
# Epoch 154/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.1877 - val_loss: 20.2622
# Epoch 155/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2440 - val_loss: 20.3418
# Epoch 156/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2071 - val_loss: 20.3591
# Epoch 157/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.3203 - val_loss: 20.3847
# Epoch 158/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.2322 - val_loss: 20.2833
# Epoch 159/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.1761 - val_loss: 20.3214
# Epoch 160/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2429 - val_loss: 20.3588
# Epoch 161/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.1586 - val_loss: 20.3087
# Epoch 162/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.2135 - val_loss: 20.2514
# Epoch 163/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.1955 - val_loss: 20.2298
# Epoch 164/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.1623 - val_loss: 20.3388
# Epoch 165/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2084 - val_loss: 20.3035
# Epoch 166/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.2818 - val_loss: 20.3076
# Epoch 167/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.1619 - val_loss: 20.2221
# Epoch 168/3000
# 7/7 [==============================] - 0s 15ms/step - loss: 19.2483 - val_loss: 20.2645
# Epoch 169/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.2041 - val_loss: 20.3664
# Epoch 170/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.1645 - val_loss: 20.2346
# Epoch 171/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.1538 - val_loss: 20.2324
# Epoch 172/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.1673 - val_loss: 20.2470
# Epoch 173/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.1735 - val_loss: 20.3022
# Epoch 174/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.1781 - val_loss: 20.2268
# Epoch 175/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.1930 - val_loss: 20.2701
# Epoch 176/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.1688 - val_loss: 20.2798
# Epoch 177/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.1411 - val_loss: 20.2391
# Epoch 178/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.1642 - val_loss: 20.3225
# Epoch 179/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.1490 - val_loss: 20.2609
# Epoch 180/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.1850 - val_loss: 20.2649
# Epoch 181/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.2272 - val_loss: 20.2776
# Epoch 182/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.1651 - val_loss: 20.2705
# Epoch 183/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.1570 - val_loss: 20.3639
# Epoch 184/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.1638 - val_loss: 20.2288
# Epoch 185/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.1782 - val_loss: 20.2172
# Epoch 186/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.1554 - val_loss: 20.2382
# Epoch 187/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.1699 - val_loss: 20.2635
# Epoch 188/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.1221 - val_loss: 20.3030
# Epoch 189/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.1648 - val_loss: 20.2261
# Epoch 190/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.1604 - val_loss: 20.2590
# Epoch 191/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.1248 - val_loss: 20.2883
# Epoch 192/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.1584 - val_loss: 20.2953
# Epoch 193/3000
# 7/7 [==============================] - 0s 14ms/step - loss: 19.1145 - val_loss: 20.2557
# Epoch 194/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.1552 - val_loss: 20.2839
# Epoch 195/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.1235 - val_loss: 20.3120
# Epoch 196/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.1487 - val_loss: 20.3046
# Epoch 197/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.1283 - val_loss: 20.2410
# Epoch 198/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.1625 - val_loss: 20.2875
# Epoch 199/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.1395 - val_loss: 20.2708
# Epoch 200/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.1239 - val_loss: 20.2873
# Epoch 201/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.1841 - val_loss: 20.2501
# Epoch 202/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.1403 - val_loss: 20.2211
# Epoch 203/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.1101 - val_loss: 20.2432
# Epoch 204/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.1337 - val_loss: 20.1949
# Epoch 205/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.1688 - val_loss: 20.2088
# Epoch 206/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.1391 - val_loss: 20.2307
# Epoch 207/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.1324 - val_loss: 20.2993
# Epoch 208/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.1460 - val_loss: 20.2710
# Epoch 209/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.1667 - val_loss: 20.1339
# Epoch 210/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.1807 - val_loss: 20.2285
# Epoch 211/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.1367 - val_loss: 20.2666
# Epoch 212/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.1788 - val_loss: 20.2005
# Epoch 213/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.1493 - val_loss: 20.2495
# Epoch 214/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.1068 - val_loss: 20.2395
# Epoch 215/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.1066 - val_loss: 20.2153
# Epoch 216/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.1071 - val_loss: 20.2033
# Epoch 217/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.1809 - val_loss: 20.2250
# Epoch 218/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.1807 - val_loss: 20.2719
# Epoch 219/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.1931 - val_loss: 20.2445
# Epoch 220/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.1356 - val_loss: 20.2434
# Epoch 221/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.1412 - val_loss: 20.2246
# Epoch 222/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.1788 - val_loss: 20.1994
# Epoch 223/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.0980 - val_loss: 20.1983
# Epoch 224/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.1129 - val_loss: 20.2899
# Epoch 225/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.1004 - val_loss: 20.2623
# Epoch 226/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.1123 - val_loss: 20.1845
# Epoch 227/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.1277 - val_loss: 20.2226
# Epoch 228/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.1036 - val_loss: 20.2857
# Epoch 229/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0853 - val_loss: 20.2020
# Epoch 230/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.0760 - val_loss: 20.2068
# Epoch 231/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.0968 - val_loss: 20.1970
# Epoch 232/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.1723 - val_loss: 20.2274
# Epoch 233/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.1078 - val_loss: 20.2629
# Epoch 234/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.0855 - val_loss: 20.2030
# Epoch 235/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.1177 - val_loss: 20.1871
# Epoch 236/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.1885 - val_loss: 20.3548
# Epoch 237/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.1446 - val_loss: 20.3727
# Epoch 238/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.1063 - val_loss: 20.1931
# Epoch 239/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.0892 - val_loss: 20.2107
# Epoch 240/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.0928 - val_loss: 20.2687
# Epoch 241/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.0925 - val_loss: 20.2570
# Epoch 242/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.1482 - val_loss: 20.2463
# Epoch 243/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.0767 - val_loss: 20.1634
# Epoch 244/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.1039 - val_loss: 20.2251
# Epoch 245/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0627 - val_loss: 20.2044
# Epoch 246/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.0809 - val_loss: 20.2086
# Epoch 247/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.1026 - val_loss: 20.1655
# Epoch 248/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.1025 - val_loss: 20.1563
# Epoch 249/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.0795 - val_loss: 20.1828
# Epoch 250/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.0985 - val_loss: 20.2498
# Epoch 251/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.0742 - val_loss: 20.2897
# Epoch 252/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.0727 - val_loss: 20.1703
# Epoch 253/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.0672 - val_loss: 20.1549
# Epoch 254/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0907 - val_loss: 20.2626
# Epoch 255/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.0943 - val_loss: 20.2527
# Epoch 256/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.0566 - val_loss: 20.2537
# Epoch 257/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.0966 - val_loss: 20.1626
# Epoch 258/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.0672 - val_loss: 20.1860
# Epoch 259/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0653 - val_loss: 20.1352
# Epoch 260/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0433 - val_loss: 20.1464
# Epoch 261/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.1084 - val_loss: 20.2390
# Epoch 262/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.0534 - val_loss: 20.2247
# Epoch 263/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.0607 - val_loss: 20.1527
# Epoch 264/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0440 - val_loss: 20.2705
# Epoch 265/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.1164 - val_loss: 20.2192
# Epoch 266/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.0806 - val_loss: 20.1462
# Epoch 267/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 19.0621 - val_loss: 20.1983
# Epoch 268/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 19.0627 - val_loss: 20.2024
# Epoch 269/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.1342 - val_loss: 20.2353
# Epoch 270/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0672 - val_loss: 20.1835
# Epoch 271/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0583 - val_loss: 20.1812
# Epoch 272/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0338 - val_loss: 20.1697
# Epoch 273/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0473 - val_loss: 20.1890
# Epoch 274/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.0179 - val_loss: 20.1213
# Epoch 275/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0178 - val_loss: 20.1436
# Epoch 276/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0256 - val_loss: 20.1337
# Epoch 277/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.0243 - val_loss: 20.1255
# Epoch 278/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.0523 - val_loss: 20.2463
# Epoch 279/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.0433 - val_loss: 20.1409
# Epoch 280/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0408 - val_loss: 20.1254
# Epoch 281/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0348 - val_loss: 20.1011
# Epoch 282/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0614 - val_loss: 20.1527
# Epoch 283/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.0311 - val_loss: 20.1488
# Epoch 284/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.0485 - val_loss: 20.1395
# Epoch 285/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0174 - val_loss: 20.1533
# Epoch 286/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0092 - val_loss: 20.1328
# Epoch 287/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.0163 - val_loss: 20.0785
# Epoch 288/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0496 - val_loss: 20.1942
# Epoch 289/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.0480 - val_loss: 20.1595
# Epoch 290/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.0309 - val_loss: 20.1250
# Epoch 291/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.0245 - val_loss: 20.1737
# Epoch 292/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.0830 - val_loss: 20.2775
# Epoch 293/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 19.0694 - val_loss: 20.1045
# Epoch 294/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.0413 - val_loss: 20.1575
# Epoch 295/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0823 - val_loss: 20.1726
# Epoch 296/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0399 - val_loss: 20.1275
# Epoch 297/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0157 - val_loss: 20.0713
# Epoch 298/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0041 - val_loss: 20.1103
# Epoch 299/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 18.9946 - val_loss: 20.1039
# Epoch 300/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.0102 - val_loss: 20.1699
# Epoch 301/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.0362 - val_loss: 20.1279
# Epoch 302/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.9880 - val_loss: 20.2133
# Epoch 303/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.0347 - val_loss: 20.1148
# Epoch 304/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.0126 - val_loss: 20.0846
# Epoch 305/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 19.0283 - val_loss: 20.1331
# Epoch 306/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 18.9940 - val_loss: 20.1139
# Epoch 307/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0044 - val_loss: 20.0687
# Epoch 308/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.0474 - val_loss: 20.2240
# Epoch 309/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.9843 - val_loss: 20.1330
# Epoch 310/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 19.0216 - val_loss: 20.0219
# Epoch 311/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 18.9689 - val_loss: 20.1002
# Epoch 312/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 18.9616 - val_loss: 20.1630
# Epoch 313/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.0155 - val_loss: 20.1284
# Epoch 314/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.9819 - val_loss: 20.0307
# Epoch 315/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.9756 - val_loss: 20.1213
# Epoch 316/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.9566 - val_loss: 20.0663
# Epoch 317/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 19.0047 - val_loss: 20.1313
# Epoch 318/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0255 - val_loss: 20.1058
# Epoch 319/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0142 - val_loss: 20.1052
# Epoch 320/3000
# 7/7 [==============================] - 0s 13ms/step - loss: 19.0157 - val_loss: 20.1860
# Epoch 321/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 18.9956 - val_loss: 20.1852
# Epoch 322/3000
# 7/7 [==============================] - 0s 15ms/step - loss: 18.9492 - val_loss: 20.0630
# Epoch 323/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.9685 - val_loss: 20.1052
# Epoch 324/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.9572 - val_loss: 20.1087
# Epoch 325/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.9365 - val_loss: 20.0755
# Epoch 326/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.9453 - val_loss: 20.0305
# Epoch 327/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.9533 - val_loss: 20.0614
# Epoch 328/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.9497 - val_loss: 20.1232
# Epoch 329/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.9966 - val_loss: 20.0687
# Epoch 330/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.9688 - val_loss: 20.1350
# Epoch 331/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.9529 - val_loss: 20.0029
# Epoch 332/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.9609 - val_loss: 20.0528
# Epoch 333/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.9551 - val_loss: 20.0572
# Epoch 334/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.9593 - val_loss: 20.0974
# Epoch 335/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.9762 - val_loss: 20.0620
# Epoch 336/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0128 - val_loss: 20.1624
# Epoch 337/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 19.0172 - val_loss: 20.2201
# Epoch 338/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.9450 - val_loss: 20.0060
# Epoch 339/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.9505 - val_loss: 20.0937
# Epoch 340/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.9707 - val_loss: 19.9792
# Epoch 341/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.9426 - val_loss: 20.0675
# Epoch 342/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.9287 - val_loss: 20.1247
# Epoch 343/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.9085 - val_loss: 20.0491
# Epoch 344/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.9281 - val_loss: 20.0390
# Epoch 345/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.9112 - val_loss: 20.0680
# Epoch 346/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.9290 - val_loss: 20.0951
# Epoch 347/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.9476 - val_loss: 20.0184
# Epoch 348/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.9558 - val_loss: 20.1377
# Epoch 349/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.9181 - val_loss: 19.9984
# Epoch 350/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 18.9410 - val_loss: 20.0099
# Epoch 351/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 18.9362 - val_loss: 20.1164
# Epoch 352/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.9230 - val_loss: 20.0518
# Epoch 353/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.8919 - val_loss: 19.9798
# Epoch 354/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.8902 - val_loss: 20.0576
# Epoch 355/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 18.9186 - val_loss: 20.0944
# Epoch 356/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.9445 - val_loss: 19.9932
# Epoch 357/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.9074 - val_loss: 20.0174
# Epoch 358/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 18.8770 - val_loss: 20.0664
# Epoch 359/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.8933 - val_loss: 19.9624
# Epoch 360/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.8965 - val_loss: 20.0397
# Epoch 361/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.9453 - val_loss: 20.0971
# Epoch 362/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.9103 - val_loss: 19.9579
# Epoch 363/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.9011 - val_loss: 19.9316
# Epoch 364/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.8820 - val_loss: 20.0108
# Epoch 365/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.8881 - val_loss: 20.0016
# Epoch 366/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.8529 - val_loss: 20.0512
# Epoch 367/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.8708 - val_loss: 19.9712
# Epoch 368/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.8265 - val_loss: 19.9575
# Epoch 369/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 18.8156 - val_loss: 19.9612
# Epoch 370/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.8572 - val_loss: 19.9257
# Epoch 371/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.8450 - val_loss: 19.9788
# Epoch 372/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.8903 - val_loss: 19.9718
# Epoch 373/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.8218 - val_loss: 19.9285
# Epoch 374/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.8293 - val_loss: 19.9615
# Epoch 375/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.8137 - val_loss: 19.9424
# Epoch 376/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.8269 - val_loss: 19.9447
# Epoch 377/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.8420 - val_loss: 19.9748
# Epoch 378/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.8041 - val_loss: 19.9779
# Epoch 379/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.8295 - val_loss: 20.0033
# Epoch 380/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.7930 - val_loss: 19.9439
# Epoch 381/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.8316 - val_loss: 19.9318
# Epoch 382/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.8302 - val_loss: 19.9165
# Epoch 383/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.7996 - val_loss: 19.9931
# Epoch 384/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.8403 - val_loss: 19.9636
# Epoch 385/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 18.8412 - val_loss: 19.9135
# Epoch 386/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 18.8398 - val_loss: 19.9461
# Epoch 387/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.8133 - val_loss: 19.9602
# Epoch 388/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.7966 - val_loss: 19.9573
# Epoch 389/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.8586 - val_loss: 19.9124
# Epoch 390/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.8174 - val_loss: 20.0210
# Epoch 391/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.8481 - val_loss: 19.9435
# Epoch 392/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.7620 - val_loss: 19.9561
# Epoch 393/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.8211 - val_loss: 19.9183
# Epoch 394/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.7532 - val_loss: 19.9498
# Epoch 395/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.7675 - val_loss: 19.8851
# Epoch 396/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.7652 - val_loss: 19.8606
# Epoch 397/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.7611 - val_loss: 19.8666
# Epoch 398/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.7701 - val_loss: 19.9439
# Epoch 399/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 18.7586 - val_loss: 19.8575
# Epoch 400/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.8501 - val_loss: 19.8244
# Epoch 401/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.7492 - val_loss: 19.8897
# Epoch 402/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.7650 - val_loss: 19.9496
# Epoch 403/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.7812 - val_loss: 19.8072
# Epoch 404/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.7245 - val_loss: 19.9106
# Epoch 405/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 18.7193 - val_loss: 19.8502
# Epoch 406/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.7392 - val_loss: 19.8164
# Epoch 407/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 18.6892 - val_loss: 19.9082
# Epoch 408/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.7644 - val_loss: 19.8341
# Epoch 409/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.7480 - val_loss: 19.9105
# Epoch 410/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.7722 - val_loss: 19.9230
# Epoch 411/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.7814 - val_loss: 19.9175
# Epoch 412/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.8026 - val_loss: 19.7754
# Epoch 413/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.6922 - val_loss: 19.9019
# Epoch 414/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.6926 - val_loss: 19.8518
# Epoch 415/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.7195 - val_loss: 19.7927
# Epoch 416/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.7335 - val_loss: 19.7955
# Epoch 417/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.8649 - val_loss: 19.8691
# Epoch 418/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.7688 - val_loss: 19.7486
# Epoch 419/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.7042 - val_loss: 19.9507
# Epoch 420/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.7169 - val_loss: 19.9007
# Epoch 421/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.6698 - val_loss: 19.7471
# Epoch 422/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.7022 - val_loss: 19.8091
# Epoch 423/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 18.7137 - val_loss: 19.7535
# Epoch 424/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 18.7692 - val_loss: 19.8302
# Epoch 425/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 18.7210 - val_loss: 19.8988
# Epoch 426/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.5743 - val_loss: 19.8050
# Epoch 427/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.6707 - val_loss: 19.7888
# Epoch 428/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.6860 - val_loss: 19.7221
# Epoch 429/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.7502 - val_loss: 19.9062
# Epoch 430/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.6349 - val_loss: 19.8251
# Epoch 431/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.6400 - val_loss: 19.7864
# Epoch 432/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.6396 - val_loss: 19.7402
# Epoch 433/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.6074 - val_loss: 19.7035
# Epoch 434/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.6378 - val_loss: 19.7135
# Epoch 435/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.5712 - val_loss: 19.8827
# Epoch 436/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.6342 - val_loss: 19.6570
# Epoch 437/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.5995 - val_loss: 19.6539
# Epoch 438/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.5906 - val_loss: 19.7352
# Epoch 439/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.5575 - val_loss: 19.7239
# Epoch 440/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 18.6015 - val_loss: 19.6946
# Epoch 441/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.5855 - val_loss: 19.8006
# Epoch 442/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.6576 - val_loss: 19.6499
# Epoch 443/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 18.6133 - val_loss: 19.7022
# Epoch 444/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.5871 - val_loss: 19.7180
# Epoch 445/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.5930 - val_loss: 19.7330
# Epoch 446/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.5091 - val_loss: 19.6801
# Epoch 447/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.5496 - val_loss: 19.5784
# Epoch 448/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.6311 - val_loss: 19.7037
# Epoch 449/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.5604 - val_loss: 19.7041
# Epoch 450/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.5469 - val_loss: 19.7050
# Epoch 451/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.5811 - val_loss: 19.5554
# Epoch 452/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.5441 - val_loss: 19.6782
# Epoch 453/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.4897 - val_loss: 19.6606
# Epoch 454/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.4927 - val_loss: 19.6249
# Epoch 455/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.5405 - val_loss: 19.6503
# Epoch 456/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.5145 - val_loss: 19.6958
# Epoch 457/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.4824 - val_loss: 19.5128
# Epoch 458/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 18.4973 - val_loss: 19.6256
# Epoch 459/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.4865 - val_loss: 19.6336
# Epoch 460/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.5078 - val_loss: 19.7016
# Epoch 461/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.4464 - val_loss: 19.5840
# Epoch 462/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.4632 - val_loss: 19.6020
# Epoch 463/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.4749 - val_loss: 19.5920
# Epoch 464/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.5245 - val_loss: 19.5553
# Epoch 465/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 18.4535 - val_loss: 19.6829
# Epoch 466/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 18.4398 - val_loss: 19.5726
# Epoch 467/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 18.4184 - val_loss: 19.6333
# Epoch 468/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 18.4287 - val_loss: 19.5271
# Epoch 469/3000
# ...
# Epoch 2847/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.5435 - val_loss: 13.4395
# Epoch 2848/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.4818 - val_loss: 13.6605
# Epoch 2849/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 11.3793 - val_loss: 13.4489
# Epoch 2850/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.3621 - val_loss: 14.0505
# Epoch 2851/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.3567 - val_loss: 13.1365
# Epoch 2852/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.2909 - val_loss: 13.2384
# Epoch 2853/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 11.2096 - val_loss: 13.4087
# Epoch 2854/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.3886 - val_loss: 13.6244
# Epoch 2855/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.4670 - val_loss: 13.2044
# Epoch 2856/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.1668 - val_loss: 13.5591
# Epoch 2857/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.4791 - val_loss: 13.4133
# Epoch 2858/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.7890 - val_loss: 14.3494
# Epoch 2859/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.5739 - val_loss: 13.3413
# Epoch 2860/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.6478 - val_loss: 13.6106
# Epoch 2861/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.6253 - val_loss: 13.6220
# Epoch 2862/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.3550 - val_loss: 13.5191
# Epoch 2863/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 11.3352 - val_loss: 13.2566
# Epoch 2864/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.2450 - val_loss: 13.1217
# Epoch 2865/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 11.3055 - val_loss: 13.5027
# Epoch 2866/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.6256 - val_loss: 13.7177
# Epoch 2867/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.3725 - val_loss: 13.5078
# Epoch 2868/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.3495 - val_loss: 13.2547
# Epoch 2869/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.0804 - val_loss: 13.0548
# Epoch 2870/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.1033 - val_loss: 13.1078
# Epoch 2871/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 11.0505 - val_loss: 13.2734
# Epoch 2872/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.1027 - val_loss: 13.1647
# Epoch 2873/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.2682 - val_loss: 13.3931
# Epoch 2874/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.4165 - val_loss: 13.2537
# Epoch 2875/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.2489 - val_loss: 13.6131
# Epoch 2876/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.5204 - val_loss: 13.0386
# Epoch 2877/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.1862 - val_loss: 12.9467
# Epoch 2878/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.4817 - val_loss: 13.6434
# Epoch 2879/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.3593 - val_loss: 13.3942
# Epoch 2880/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.2060 - val_loss: 13.9804
# Epoch 2881/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 12.1935 - val_loss: 13.7707
# Epoch 2882/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 12.0227 - val_loss: 13.4550
# Epoch 2883/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.4364 - val_loss: 13.5726
# Epoch 2884/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.2955 - val_loss: 13.5138
# Epoch 2885/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.3027 - val_loss: 13.1092
# Epoch 2886/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 11.1686 - val_loss: 13.1039
# Epoch 2887/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.0305 - val_loss: 12.9250
# Epoch 2888/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 11.2431 - val_loss: 13.8929
# Epoch 2889/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.3901 - val_loss: 13.4552
# Epoch 2890/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.2488 - val_loss: 13.3108
# Epoch 2891/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 11.2020 - val_loss: 13.0702
# Epoch 2892/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.1675 - val_loss: 13.3749
# Epoch 2893/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 11.2571 - val_loss: 13.7219
# Epoch 2894/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.6159 - val_loss: 13.5164
# Epoch 2895/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.6006 - val_loss: 13.3191
# Epoch 2896/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.2485 - val_loss: 13.7788
# Epoch 2897/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.4492 - val_loss: 13.3481
# Epoch 2898/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.5232 - val_loss: 13.3278
# Epoch 2899/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.2567 - val_loss: 13.6627
# Epoch 2900/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.0696 - val_loss: 13.2059
# Epoch 2901/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.1562 - val_loss: 13.2808
# Epoch 2902/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 11.1824 - val_loss: 13.2416
# Epoch 2903/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 11.1699 - val_loss: 13.6545
# Epoch 2904/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.2862 - val_loss: 13.0135
# Epoch 2905/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 11.1092 - val_loss: 13.3772
# Epoch 2906/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.0376 - val_loss: 13.0297
# Epoch 2907/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.2459 - val_loss: 13.7783
# Epoch 2908/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.6072 - val_loss: 13.1373
# Epoch 2909/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 11.4562 - val_loss: 13.6812
# Epoch 2910/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.5558 - val_loss: 14.6226
# Epoch 2911/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.9103 - val_loss: 13.4363
# Epoch 2912/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.6752 - val_loss: 13.1506
# Epoch 2913/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.6701 - val_loss: 13.1975
# Epoch 2914/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.2904 - val_loss: 13.7641
# Epoch 2915/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.4390 - val_loss: 13.7600
# Epoch 2916/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.1976 - val_loss: 13.2543
# Epoch 2917/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 11.4431 - val_loss: 13.3612
# Epoch 2918/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.2812 - val_loss: 13.6454
# Epoch 2919/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.4335 - val_loss: 13.7362
# Epoch 2920/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 11.3499 - val_loss: 13.4301
# Epoch 2921/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 11.4747 - val_loss: 13.3462
# Epoch 2922/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 11.2450 - val_loss: 13.3544
# Epoch 2923/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.2498 - val_loss: 13.4885
# Epoch 2924/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.1598 - val_loss: 13.3308
# Epoch 2925/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.3985 - val_loss: 13.1658
# Epoch 2926/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.1871 - val_loss: 13.3530
# Epoch 2927/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.3376 - val_loss: 14.0394
# Epoch 2928/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.9608 - val_loss: 13.6405
# Epoch 2929/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.4315 - val_loss: 14.0778
# Epoch 2930/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.9518 - val_loss: 13.6214
# Epoch 2931/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 12.2539 - val_loss: 13.8788
# Epoch 2932/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.7345 - val_loss: 13.8400
# Epoch 2933/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 11.5656 - val_loss: 13.4136
# Epoch 2934/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 11.4706 - val_loss: 13.2233
# Epoch 2935/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.3932 - val_loss: 13.6288
# Epoch 2936/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.5441 - val_loss: 13.1906
# Epoch 2937/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.2695 - val_loss: 13.2791
# Epoch 2938/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 11.3053 - val_loss: 13.1352
# Epoch 2939/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.0358 - val_loss: 13.0198
# Epoch 2940/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.3281 - val_loss: 13.3747
# Epoch 2941/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.2353 - val_loss: 13.3179
# Epoch 2942/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.2971 - val_loss: 13.4174
# Epoch 2943/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.1788 - val_loss: 13.2234
# Epoch 2944/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.1048 - val_loss: 13.5344
# Epoch 2945/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.2666 - val_loss: 13.6498
# Epoch 2946/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.3066 - val_loss: 13.4148
# Epoch 2947/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.6401 - val_loss: 14.8892
# Epoch 2948/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 12.1127 - val_loss: 13.2421
# Epoch 2949/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 11.5327 - val_loss: 13.6116
# Epoch 2950/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.2595 - val_loss: 13.1992
# Epoch 2951/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 11.4514 - val_loss: 13.4563
# Epoch 2952/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.3468 - val_loss: 13.4905
# Epoch 2953/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.3726 - val_loss: 13.1701
# Epoch 2954/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.1511 - val_loss: 13.1082
# Epoch 2955/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.0579 - val_loss: 13.0952
# Epoch 2956/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.0694 - val_loss: 12.9195
# Epoch 2957/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.2927 - val_loss: 13.1451
# Epoch 2958/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.3318 - val_loss: 13.4365
# Epoch 2959/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.2046 - val_loss: 13.4171
# Epoch 2960/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 11.2508 - val_loss: 13.5743
# Epoch 2961/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.7043 - val_loss: 13.3997
# Epoch 2962/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.2307 - val_loss: 13.1855
# Epoch 2963/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.1079 - val_loss: 13.2307
# Epoch 2964/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 11.1887 - val_loss: 13.2340
# Epoch 2965/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.0934 - val_loss: 13.3859
# Epoch 2966/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.2943 - val_loss: 13.1578
# Epoch 2967/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.2450 - val_loss: 13.3976
# Epoch 2968/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 11.2686 - val_loss: 13.2268
# Epoch 2969/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.0377 - val_loss: 13.1962
# Epoch 2970/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.1785 - val_loss: 13.2998
# Epoch 2971/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.2639 - val_loss: 13.2785
# Epoch 2972/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.4756 - val_loss: 13.2756
# Epoch 2973/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.4163 - val_loss: 13.5012
# Epoch 2974/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.1316 - val_loss: 12.9880
# Epoch 2975/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.1369 - val_loss: 13.8856
# Epoch 2976/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.2500 - val_loss: 13.0310
# Epoch 2977/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 10.9971 - val_loss: 12.9833
# Epoch 2978/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 10.9643 - val_loss: 12.9445
# Epoch 2979/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.0557 - val_loss: 13.2164
# Epoch 2980/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.1463 - val_loss: 13.7785
# Epoch 2981/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.4757 - val_loss: 13.3279
# Epoch 2982/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.4147 - val_loss: 13.4526
# Epoch 2983/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.3778 - val_loss: 13.5782
# Epoch 2984/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.1974 - val_loss: 13.1125
# Epoch 2985/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.0530 - val_loss: 13.0954
# Epoch 2986/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.0675 - val_loss: 13.0499
# Epoch 2987/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.0940 - val_loss: 13.3124
# Epoch 2988/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 11.2035 - val_loss: 13.2311
# Epoch 2989/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.0977 - val_loss: 12.9411
# Epoch 2990/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 11.1342 - val_loss: 13.4206
# Epoch 2991/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.4610 - val_loss: 13.1630
# Epoch 2992/3000
# 7/7 [==============================] - 0s 12ms/step - loss: 11.3417 - val_loss: 13.4942
# Epoch 2993/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.1131 - val_loss: 13.9974
# Epoch 2994/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.5673 - val_loss: 13.0891
# Epoch 2995/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 10.9846 - val_loss: 13.5705
# Epoch 2996/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.3262 - val_loss: 13.1785
# Epoch 2997/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.3307 - val_loss: 13.3214
# Epoch 2998/3000
# 7/7 [==============================] - 0s 10ms/step - loss: 11.4223 - val_loss: 13.2997
# Epoch 2999/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 11.2142 - val_loss: 13.2948
# Epoch 3000/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.0294 - val_loss: 13.4145

# %% [markdown]
# ##### Define loss curve

# %%
ax = obj.plot_convergence(history)
# ax = utility.custom_figure_axis(ax, fontsize=4, rotation = 0)
ax.set_ylabel("Loss", labelpad=1)
ax.set_xlabel("Epoch", labelpad=1)
ax.set_title("Loss curve", fontsize=10)

ax = utility.custom_figure_axis(ax, show_ticks = True, rotation =0, tick_fontsize = 10, label_fontsize = 10, legend_fontsize = 10)
# ax.set_yscale("log")
ax.legend(ncol= 1, fontsize = 9, frameon =False)
plt.savefig("simulated2_new_loss.pdf", dpi = 300, transparent=False, bbox_inches="tight")

# %% [markdown]
# ##### Test data performance

# %%
test_loss = model.evaluate(X_test, y_test)
print("Test loss:", test_loss)
# Out:
# 32/32 [==============================] - 0s 1ms/step - loss: 10.9088
# Test loss: 10.908834457397461

# %% [markdown]
# ##### Define torch optimizer

# %%
import numpy as np
import torch
import torch.optim as optim

def torch_optimization(args, lr, num_steps, f, tol=1e-5, patience=100):
    """
    Performs optimization using PyTorch's Adam optimizer with early stopping 
    when loss difference is below a threshold for a given number of epochs.

    Parameters:
    args (tuple): Initial values (x, y).
    lr (float): Learning rate.
    num_steps (int): Maximum number of optimization steps.
    f (function): Function to be minimized.
    tol (float): Threshold for stopping when loss difference is small.
    patience (int): Number of consecutive epochs with small loss change before stopping.

    Returns:
    np.array: Optimized values of (x, y).
    list: List of function values (loss) at each epoch.
    """

    x = torch.tensor(args[0], dtype=torch.float32, requires_grad=True)
    y = torch.tensor(args[1], dtype=torch.float32, requires_grad=True)

    optimizer = optim.Adam([x, y], lr=lr)

    function_values = []  # Store f(x, y) values at each epoch
    stable_count = 0  # Counter for consecutive small changes

    for step in range(num_steps):
        optimizer.zero_grad()
        
        loss = f((x, y))  # Compute function value
        function_values.append(loss.item())  # Store function value
        
        loss.backward()  # Compute gradients
        optimizer.step()  # Update parameters

        # Check for early stopping
        if step > 0:
            loss_diff = abs(function_values[-1] - function_values[-2])
            if loss_diff < tol:
                stable_count += 1
            else:
                stable_count = 0  # Reset if loss difference is significant

            if stable_count >= patience:
                print(f"Early stopping at step {step} (loss change < {tol} for {patience} consecutive epochs)")
                break

    return np.array([x.item(), y.item()]), function_values

# %% [markdown]
# ##### Run 10000 iteration to optimize funtion from [-5,5] with step size of 1 with various method

# %%
lr = 0.001
max_iters = 10000

# %% [markdown]
# ##### Store the result of central differentiation

# %%
# import importlib
# importlib.reload(utility)

# %%
c = 0

df_cd = pd.DataFrame(columns =["X_start",  "y_start", "X_gd_cd", "y_gd_cd"])

for i in list(range(-5, 6, 1)):
    for j in list(range(-5, 6, 1)):

        print(f"currently running for x = {i} and y = {j}")
        x0 = np.array([i*1.0, j*1.0])
        X_gd, y_gd, history_gd = obj.optimize_function_with_central_difference(f=f, x0=x0, learning_rate=lr, max_iters=max_iters, tol=1e-5, patience =100)
        df_cd.loc[c, ["X_gd_cd", "y_gd_cd"]] = X_gd, y_gd
        df_cd.loc[c, "y_start"] = f(x0)
        df_cd.loc[c, "X_start"] = x0


        c = c + 1

        X_gd, y_gd, x0 =  [None] * 3
# Out:
# currently running for x = -5 and y = -5
# Early stopping at iteration 183 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = -4
# Early stopping at iteration 172 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = -3
# Early stopping at iteration 164 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = -2
# Early stopping at iteration 2438 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = -1
# Early stopping at iteration 2410 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = 0
# Early stopping at iteration 2401 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = 1
# Early stopping at iteration 2410 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = 2
# Early stopping at iteration 2438 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = 3
# Early stopping at iteration 164 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = 4
# Early stopping at iteration 172 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = 5
# Early stopping at iteration 183 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = -5
# Early stopping at iteration 172 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = -4
# Early stopping at iteration 163 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = -3
# Early stopping at iteration 156 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = -2
# Early stopping at iteration 2346 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = -1
# Early stopping at iteration 2304 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = 0
# Early stopping at iteration 2289 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = 1
# Early stopping at iteration 2304 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = 2
# Early stopping at iteration 2346 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = 3
# Early stopping at iteration 156 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = 4
# Early stopping at iteration 163 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = 5
# Early stopping at iteration 172 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = -5
# Early stopping at iteration 164 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = -4
# Early stopping at iteration 156 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = -3
# Early stopping at iteration 145 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = -2
# Early stopping at iteration 2239 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = -1
# Early stopping at iteration 2172 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = 0
# Early stopping at iteration 2145 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = 1
# Early stopping at iteration 2172 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = 2
# Early stopping at iteration 2239 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = 3
# Early stopping at iteration 145 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = 4
# Early stopping at iteration 156 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = 5
# Early stopping at iteration 164 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = -5
# Early stopping at iteration 2438 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = -4
# Early stopping at iteration 2346 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = -3
# Early stopping at iteration 2239 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = -2
# Early stopping at iteration 2116 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = -1
# Early stopping at iteration 1999 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = 0
# Early stopping at iteration 1943 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = 1
# Early stopping at iteration 1999 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = 2
# Early stopping at iteration 2116 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = 3
# Early stopping at iteration 2239 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = 4
# Early stopping at iteration 2346 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = 5
# Early stopping at iteration 2438 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = -5
# Early stopping at iteration 2410 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = -4
# Early stopping at iteration 2304 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = -3
# Early stopping at iteration 2172 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = -2
# Early stopping at iteration 1999 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = -1
# Early stopping at iteration 1770 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = 0
# Early stopping at iteration 1597 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = 1
# Early stopping at iteration 1770 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = 2
# Early stopping at iteration 1999 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = 3
# Early stopping at iteration 2172 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = 4
# Early stopping at iteration 2304 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = 5
# Early stopping at iteration 2410 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = -5
# Early stopping at iteration 2401 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = -4
# Early stopping at iteration 2289 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = -3
# Early stopping at iteration 2145 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = -2
# Early stopping at iteration 1943 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = -1
# Early stopping at iteration 1597 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = 0
# Early stopping at iteration 100 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = 1
# Early stopping at iteration 1597 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = 2
# Early stopping at iteration 1943 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = 3
# Early stopping at iteration 2145 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = 4
# Early stopping at iteration 2289 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = 5
# Early stopping at iteration 2401 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = -5
# Early stopping at iteration 2410 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = -4
# Early stopping at iteration 2304 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = -3
# Early stopping at iteration 2172 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = -2
# Early stopping at iteration 1999 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = -1
# Early stopping at iteration 1770 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = 0
# Early stopping at iteration 1597 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = 1
# Early stopping at iteration 1770 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = 2
# Early stopping at iteration 1999 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = 3
# Early stopping at iteration 2172 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = 4
# Early stopping at iteration 2304 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = 5
# Early stopping at iteration 2410 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = -5
# Early stopping at iteration 2438 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = -4
# Early stopping at iteration 2346 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = -3
# Early stopping at iteration 2239 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = -2
# Early stopping at iteration 2116 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = -1
# Early stopping at iteration 1999 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = 0
# Early stopping at iteration 1943 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = 1
# Early stopping at iteration 1999 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = 2
# Early stopping at iteration 2116 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = 3
# Early stopping at iteration 2239 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = 4
# Early stopping at iteration 2346 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = 5
# Early stopping at iteration 2438 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = -5
# Early stopping at iteration 164 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = -4
# Early stopping at iteration 156 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = -3
# Early stopping at iteration 145 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = -2
# Early stopping at iteration 2239 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = -1
# Early stopping at iteration 2172 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = 0
# Early stopping at iteration 2145 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = 1
# Early stopping at iteration 2172 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = 2
# Early stopping at iteration 2239 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = 3
# Early stopping at iteration 145 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = 4
# Early stopping at iteration 156 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = 5
# Early stopping at iteration 164 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = -5
# Early stopping at iteration 172 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = -4
# Early stopping at iteration 163 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = -3
# Early stopping at iteration 156 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = -2
# Early stopping at iteration 2346 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = -1
# Early stopping at iteration 2304 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = 0
# Early stopping at iteration 2289 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = 1
# Early stopping at iteration 2304 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = 2
# Early stopping at iteration 2346 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = 3
# Early stopping at iteration 156 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = 4
# Early stopping at iteration 163 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = 5
# Early stopping at iteration 172 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = -5
# Early stopping at iteration 183 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = -4
# Early stopping at iteration 172 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = -3
# Early stopping at iteration 164 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = -2
# Early stopping at iteration 2438 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = -1
# Early stopping at iteration 2410 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = 0
# Early stopping at iteration 2401 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = 1
# Early stopping at iteration 2410 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = 2
# Early stopping at iteration 2438 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = 3
# Early stopping at iteration 164 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = 4
# Early stopping at iteration 172 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = 5
# Early stopping at iteration 183 (loss change < 1e-05 for 100 consecutive steps)

# %%
# df_cd

# %% [markdown]
# ##### store result for proposed method

# %%
c = 0


df_proposed = pd.DataFrame(columns =["X_start",  "y_start", "X_new", "y_new"])

for i in list(range(-5, 6, 1)):
    for j in list(range(-5, 6, 1)):

        print(f"currently running for x = {i} and y = {j}")
        x0 = np.array([i*1.0, j*1.0])
        X_new, y_new, history_proposed = obj.optimize_function(f=f, model = model, x0=x0, learning_rate=lr, max_iters=max_iters, tol=1e-5)
        df_proposed.loc[c, ["X_new", "y_new"]] = X_new, y_new
        df_proposed.loc[c, "y_start"] = f(x0)
        df_proposed.loc[c, "X_start"] = x0

        c = c + 1

        X_new, y_new, x0 =  [None] * 3

    #     break
    # break
# Out:
# currently running for x = -5 and y = -5
# Early stopping at iteration 805 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = -4
# Early stopping at iteration 613 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = -3
# Early stopping at iteration 601 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = -2
# Early stopping at iteration 2504 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = -1
# Early stopping at iteration 2483 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = 0
# Early stopping at iteration 2413 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = 1
# Early stopping at iteration 2424 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = 2
# Early stopping at iteration 2867 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = 3
# Early stopping at iteration 574 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = 4
# Early stopping at iteration 579 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -5 and y = 5
# Early stopping at iteration 592 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = -5
# Early stopping at iteration 970 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = -4
# Early stopping at iteration 465 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = -3
# Early stopping at iteration 450 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = -2
# Early stopping at iteration 2402 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = -1
# Early stopping at iteration 2381 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = 0
# Early stopping at iteration 2298 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = 1
# Early stopping at iteration 2442 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = 2
# Early stopping at iteration 2782 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = 3
# Early stopping at iteration 395 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = 4
# Early stopping at iteration 426 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -4 and y = 5
# Early stopping at iteration 734 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = -5
# Early stopping at iteration 782 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = -4
# Early stopping at iteration 465 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = -3
# Early stopping at iteration 350 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = -2
# Early stopping at iteration 2267 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = -1
# Early stopping at iteration 2250 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = 0
# Early stopping at iteration 2150 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = 1
# Early stopping at iteration 2582 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = 2
# Early stopping at iteration 2699 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = 3
# Early stopping at iteration 295 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = 4
# Early stopping at iteration 424 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -3 and y = 5
# Early stopping at iteration 715 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = -5
# Early stopping at iteration 3030 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = -4
# Early stopping at iteration 2836 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = -3
# Early stopping at iteration 2598 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = -2
# Early stopping at iteration 2062 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = -1
# Early stopping at iteration 2074 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = 0
# Early stopping at iteration 1947 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = 1
# Early stopping at iteration 2440 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = 2
# Early stopping at iteration 2579 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = 3
# Early stopping at iteration 2656 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = 4
# Early stopping at iteration 2538 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -2 and y = 5
# Early stopping at iteration 2429 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = -5
# Early stopping at iteration 3034 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = -4
# Early stopping at iteration 2917 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = -3
# Early stopping at iteration 2728 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = -2
# Early stopping at iteration 2366 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = -1
# Early stopping at iteration 1722 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = 0
# Early stopping at iteration 1610 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = 1
# Early stopping at iteration 2248 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = 2
# Early stopping at iteration 2221 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = 3
# Early stopping at iteration 2035 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = 4
# Early stopping at iteration 2104 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = -1 and y = 5
# Early stopping at iteration 2265 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = -5
# Early stopping at iteration 2984 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = -4
# Early stopping at iteration 2861 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = -3
# Early stopping at iteration 2699 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = -2
# Early stopping at iteration 2472 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = -1
# Early stopping at iteration 2105 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = 0
# Early stopping at iteration 100 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = 1
# Early stopping at iteration 1453 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = 2
# Early stopping at iteration 1814 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = 3
# Early stopping at iteration 2036 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = 4
# Early stopping at iteration 2207 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 0 and y = 5
# Early stopping at iteration 2346 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = -5
# Early stopping at iteration 2943 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = -4
# Early stopping at iteration 2806 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = -3
# Early stopping at iteration 2610 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = -2
# Early stopping at iteration 2368 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = -1
# Early stopping at iteration 1976 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = 0
# Early stopping at iteration 1723 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = 1
# Early stopping at iteration 1920 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = 2
# Early stopping at iteration 2066 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = 3
# Early stopping at iteration 2216 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = 4
# Early stopping at iteration 2338 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 1 and y = 5
# Early stopping at iteration 2437 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = -5
# Early stopping at iteration 2869 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = -4
# Early stopping at iteration 2758 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = -3
# Early stopping at iteration 2623 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = -2
# Early stopping at iteration 2358 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = -1
# Early stopping at iteration 2004 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = 0
# Early stopping at iteration 2125 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = 1
# Early stopping at iteration 2196 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = 2
# Early stopping at iteration 2280 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = 3
# Early stopping at iteration 2385 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = 4
# Early stopping at iteration 2437 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 2 and y = 5
# Early stopping at iteration 2540 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = -5
# Early stopping at iteration 600 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = -4
# Early stopping at iteration 422 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = -3
# Early stopping at iteration 311 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = -2
# Early stopping at iteration 2330 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = -1
# Early stopping at iteration 2190 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = 0
# Early stopping at iteration 2337 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = 1
# Early stopping at iteration 2391 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = 2
# Early stopping at iteration 2460 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = 3
# Early stopping at iteration 482 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = 4
# Early stopping at iteration 547 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 3 and y = 5
# Early stopping at iteration 716 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = -5
# Early stopping at iteration 643 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = -4
# Early stopping at iteration 442 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = -3
# Early stopping at iteration 409 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = -2
# Early stopping at iteration 2364 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = -1
# Early stopping at iteration 2352 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = 0
# Early stopping at iteration 2485 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = 1
# Early stopping at iteration 2564 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = 2
# Early stopping at iteration 2537 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = 3
# Early stopping at iteration 609 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = 4
# Early stopping at iteration 599 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 4 and y = 5
# Early stopping at iteration 795 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = -5
# Early stopping at iteration 691 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = -4
# Early stopping at iteration 555 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = -3
# Early stopping at iteration 525 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = -2
# Early stopping at iteration 2448 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = -1
# Early stopping at iteration 2476 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = 0
# Early stopping at iteration 2611 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = 1
# Early stopping at iteration 2689 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = 2
# Early stopping at iteration 2633 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = 3
# Early stopping at iteration 736 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = 4
# Early stopping at iteration 753 (loss change < 1e-05 for 100 consecutive steps)
# currently running for x = 5 and y = 5
# Early stopping at iteration 848 (loss change < 1e-05 for 100 consecutive steps)

# %% [markdown]
# ##### Store result for autograd

# %%
c = 0

df_autograd = pd.DataFrame(columns =["X_start",  "y_start", "X_autograd", "y_autograd"])

for i in list(range(-5, 6, 1)):

    for j in list(range(-5, 6, 1)):

        print(f"currently running for x = {i} and y = {j}")
        x0 = np.array([i*1.0, j*1.0])

        x_torch, history_autograd = torch_optimization(args=x0, lr = lr, num_steps=max_iters, f=parabolic_loss_with_dips_3D_torch)

        df_autograd.loc[c, "y_start"] = f(x0)
        df_autograd.loc[c, "X_start"] = x0

        df_autograd.loc[c, "X_autograd"] = x_torch
        df_autograd.loc[c, "y_autograd"] = f(x_torch)

        x_torch, x0 = [None] *2


        c = c + 1
# Out:
# currently running for x = -5 and y = -5
# Early stopping at step 455 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -5 and y = -4
# Early stopping at step 402 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -5 and y = -3
# Early stopping at step 390 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -5 and y = -2
# Early stopping at step 7914 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -5 and y = -1
# Early stopping at step 7915 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -5 and y = 0
# Early stopping at step 7915 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -5 and y = 1
# Early stopping at step 7915 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -5 and y = 2
# Early stopping at step 7914 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -5 and y = 3
# Early stopping at step 390 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -5 and y = 4
# Early stopping at step 402 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -5 and y = 5
# Early stopping at step 455 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -4 and y = -5
# Early stopping at step 400 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -4 and y = -4
# Early stopping at step 312 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -4 and y = -3
# Early stopping at step 290 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -4 and y = -2
# Early stopping at step 6613 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -4 and y = -1
# Early stopping at step 6614 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -4 and y = 0
# Early stopping at step 6614 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -4 and y = 1
# Early stopping at step 6614 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -4 and y = 2
# Early stopping at step 6613 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -4 and y = 3
# Early stopping at step 290 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -4 and y = 4
# Early stopping at step 312 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -4 and y = 5
# Early stopping at step 402 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -3 and y = -5
# Early stopping at step 390 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -3 and y = -4
# Early stopping at step 290 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -3 and y = -3
# Early stopping at step 199 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -3 and y = -2
# Early stopping at step 5210 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -3 and y = -1
# Early stopping at step 5212 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -3 and y = 0
# Early stopping at step 5212 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -3 and y = 1
# Early stopping at step 5212 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -3 and y = 2
# Early stopping at step 5210 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -3 and y = 3
# Early stopping at step 199 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -3 and y = 4
# Early stopping at step 290 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -3 and y = 5
# Early stopping at step 390 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -2 and y = -5
# Early stopping at step 7914 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -2 and y = -4
# Early stopping at step 6613 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -2 and y = -3
# Early stopping at step 5210 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -2 and y = -2
# Early stopping at step 3826 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -2 and y = -1
# Early stopping at step 3653 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -2 and y = 0
# Early stopping at step 3653 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -2 and y = 1
# Early stopping at step 3653 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -2 and y = 2
# Early stopping at step 3826 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -2 and y = 3
# Early stopping at step 5210 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -2 and y = 4
# Early stopping at step 6613 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -2 and y = 5
# Early stopping at step 7914 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -1 and y = -5
# Early stopping at step 7915 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -1 and y = -4
# Early stopping at step 6614 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -1 and y = -3
# Early stopping at step 5212 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -1 and y = -2
# Early stopping at step 3653 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -1 and y = -1
# Early stopping at step 2008 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -1 and y = 0
# Early stopping at step 1883 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -1 and y = 1
# Early stopping at step 2008 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -1 and y = 2
# Early stopping at step 3653 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -1 and y = 3
# Early stopping at step 5212 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -1 and y = 4
# Early stopping at step 6614 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = -1 and y = 5
# Early stopping at step 7915 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 0 and y = -5
# Early stopping at step 7915 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 0 and y = -4
# Early stopping at step 6614 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 0 and y = -3
# Early stopping at step 5212 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 0 and y = -2
# Early stopping at step 3653 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 0 and y = -1
# Early stopping at step 1883 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 0 and y = 0
# Early stopping at step 100 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 0 and y = 1
# Early stopping at step 1883 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 0 and y = 2
# Early stopping at step 3653 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 0 and y = 3
# Early stopping at step 5212 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 0 and y = 4
# Early stopping at step 6614 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 0 and y = 5
# Early stopping at step 7915 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 1 and y = -5
# Early stopping at step 7915 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 1 and y = -4
# Early stopping at step 6614 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 1 and y = -3
# Early stopping at step 5212 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 1 and y = -2
# Early stopping at step 3653 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 1 and y = -1
# Early stopping at step 2008 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 1 and y = 0
# Early stopping at step 1883 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 1 and y = 1
# Early stopping at step 2008 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 1 and y = 2
# Early stopping at step 3653 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 1 and y = 3
# Early stopping at step 5212 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 1 and y = 4
# Early stopping at step 6614 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 1 and y = 5
# Early stopping at step 7915 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 2 and y = -5
# Early stopping at step 7914 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 2 and y = -4
# Early stopping at step 6613 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 2 and y = -3
# Early stopping at step 5210 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 2 and y = -2
# Early stopping at step 3826 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 2 and y = -1
# Early stopping at step 3653 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 2 and y = 0
# Early stopping at step 3653 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 2 and y = 1
# Early stopping at step 3653 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 2 and y = 2
# Early stopping at step 3826 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 2 and y = 3
# Early stopping at step 5210 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 2 and y = 4
# Early stopping at step 6613 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 2 and y = 5
# Early stopping at step 7914 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 3 and y = -5
# Early stopping at step 390 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 3 and y = -4
# Early stopping at step 290 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 3 and y = -3
# Early stopping at step 199 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 3 and y = -2
# Early stopping at step 5210 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 3 and y = -1
# Early stopping at step 5212 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 3 and y = 0
# Early stopping at step 5212 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 3 and y = 1
# Early stopping at step 5212 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 3 and y = 2
# Early stopping at step 5210 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 3 and y = 3
# Early stopping at step 199 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 3 and y = 4
# Early stopping at step 290 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 3 and y = 5
# Early stopping at step 390 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 4 and y = -5
# Early stopping at step 402 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 4 and y = -4
# Early stopping at step 312 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 4 and y = -3
# Early stopping at step 290 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 4 and y = -2
# Early stopping at step 6613 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 4 and y = -1
# Early stopping at step 6614 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 4 and y = 0
# Early stopping at step 6614 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 4 and y = 1
# Early stopping at step 6614 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 4 and y = 2
# Early stopping at step 6613 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 4 and y = 3
# Early stopping at step 290 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 4 and y = 4
# Early stopping at step 315 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 4 and y = 5
# Early stopping at step 402 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 5 and y = -5
# Early stopping at step 455 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 5 and y = -4
# Early stopping at step 411 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 5 and y = -3
# Early stopping at step 390 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 5 and y = -2
# Early stopping at step 7914 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 5 and y = -1
# Early stopping at step 7915 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 5 and y = 0
# Early stopping at step 7915 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 5 and y = 1
# Early stopping at step 7915 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 5 and y = 2
# Early stopping at step 7914 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 5 and y = 3
# Early stopping at step 390 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 5 and y = 4
# Early stopping at step 402 (loss change < 1e-05 for 100 consecutive epochs)
# currently running for x = 5 and y = 5
# Early stopping at step 455 (loss change < 1e-05 for 100 consecutive epochs)

# %%
df_autograd["y_start"] = df_autograd["y_start"].apply(pd.to_numeric, errors='coerce')
df_autograd["X_start"] = df_autograd["X_start"].astype(str)

df_proposed["y_start"] = df_proposed["y_start"].apply(pd.to_numeric, errors='coerce')
df_proposed["X_start"] = df_proposed["X_start"].astype(str)

df_cd["y_start"] = df_cd["y_start"].apply(pd.to_numeric, errors='coerce')
df_cd["X_start"] = df_cd["X_start"].astype(str)

# %%
df = pd.merge(df_autograd, df_proposed).merge(df_cd)
df["y_autograd"] = df["y_autograd"].apply(pd.to_numeric, errors='coerce')
df["y_gd_cd"] = df["y_gd_cd"].apply(pd.to_numeric, errors='coerce')

# %%
# df

# %% [markdown]
# ##### Show result

# %% [markdown]
# #### pickle result

# %%
res = {"model": model, "history_autograd": history_autograd, "history_proposed": history_proposed, "history_gd": history_gd, "result": df}

# Save (pickle) the dictionary to a file
with open("simulated2_new.pkl", "wb") as file:
    pickle.dump(res, file)

# %%
# Load (unpickle) the dictionary from the file
with open("simulated2_new.pkl", "rb") as file:
    loaded_data = pickle.load(file)

# print(loaded_data)

# %% [markdown]
# ##### Test if pickled model is working

# %%
loaded_model1 = loaded_data["model"]
# test_loss = loaded_model.evaluate(X_test, y_test)
print("Test loss:", loaded_model1.evaluate(X_test, y_test))
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 10.9088
# Test loss: 10.908834457397461

# %% [markdown]
# ##### Show combined result

# %%
df
# Out:
#        X_start    y_start                                        X_autograd  \
# 0    [-5. -5.]  39.864787          [-4.863097190856934, -4.863097190856934]
# 1    [-5. -4.]  30.796954         [-4.869205474853516, -3.8988633155822754]
# 2    [-5. -3.]  23.864787         [-4.871736526489258, -2.9404921531677246]
# 3    [-5. -2.]  28.932167  [-0.041789550334215164, -1.8172685013877214e-19]
# 4    [-5. -1.]  26.000000    [-0.041760776191949844, 2.312142466135948e-43]
# ..         ...        ...                                               ...
# 116    [5. 1.]  26.000000    [0.041760776191949844, -2.312142466135948e-43]
# 117    [5. 2.]  28.932167    [0.041789550334215164, 1.8172685013877214e-19]
# 118    [5. 3.]  23.864787           [4.871736526489258, 2.9404921531677246]
# 119    [5. 4.]  30.796954           [4.869205474853516, 3.8988633155822754]
# 120    [5. 5.]  39.864787            [4.863097190856934, 4.863097190856934]
#
#      y_autograd                                           X_new     y_new  \
# 0     38.563427       [-2.8429271702594683, -2.918573692511977]  8.011546
# 1     29.782905        [-2.842927149649121, -2.918573697319837]  8.011546
# 2     23.077299      [-2.8429271996404246, -2.9185737078680756]  8.011546
# 3      0.001746   [-0.021375733503383287, -0.08280086155718891]  0.007313
# 4      0.001744     [-0.02544690084548762, -0.0823053142848984]  0.007422
# ..          ...                                             ...       ...
# 116    0.001744    [0.003951328588300385, -0.00417901408218313]  0.000033
# 117    0.001746  [-0.001110404438804835, 0.0006989767862251028]  0.000002
# 118   23.077299         [2.7838744909401214, 2.941456676501952]  8.584207
# 119   29.782905        [2.7838745022161078, 2.9414566754176583]  8.584207
# 120   38.563427         [2.7838744604273913, 2.941456672112235]  8.584208
#
#                                            X_gd_cd    y_gd_cd
# 0         [-4.862655222267804, -4.862655222267804]  38.563417
# 1         [-4.868877244181498, -3.898772839550709]  29.782902
# 2        [-4.871453262682053, -2.9404667081137177]  23.077296
# 3    [-0.03796058012738936, -0.015313495203673444]   0.001676
# 4    [-0.04013973555026714, -0.008027947189230967]   0.001676
# ..                                             ...        ...
# 116    [0.04013973555026714, 0.008027947189230967]   0.001676
# 117   [0.037960580127403526, 0.015313495203675982]   0.001676
# 118        [4.871453262680809, 2.9404667081124742]  23.077296
# 119       [4.8688772441820305, 3.8987728395508867]  29.782902
# 120           [4.86265522226887, 4.86265522226887]  38.563417
#
# [121 rows x 8 columns]

# %% [markdown]
# ##### Density plot of optimized y (left) and optimized y with various method with various starting point (right)

# %%
fig, ax = plt.subplots(1, 2, dpi = 300, figsize = (4,2))
fig.subplots_adjust(left=0.02, right=0.98, top=0.98, bottom=0.02)
import seaborn as sns

ax[0] = sns.kdeplot(data = df, x = "y_autograd", ax=ax[0], label = "AutoGrad", lw = 0.5)
ax[0] = sns.kdeplot(data = df, x = "y_new", ax=ax[0], label = "Our method", lw = 0.5)
ax[0] = sns.kdeplot(data = df, x = "y_gd_cd", ax=ax[0], label = "GD with Central Difference", lw = 0.5)
ax[0].legend(ncol = 1, fontsize=4, frameon=False)
ax[0].set_xlabel("Optimized y")

# ax[0] = utility.custom_figure_axis(ax[0], rotation=0, fontsize=5)
# 
ax[0] = utility.custom_figure_axis(ax[0], show_ticks = True, rotation =0, tick_fontsize = 10, label_fontsize = 10, legend_fontsize = 3)


ax[1] = sns.lineplot(data = df, x = range(df.shape[0]), y = "y_autograd", ax=ax[1], label = "AutoGrad", lw = 0.5)
ax[1] = sns.lineplot(data = df, x = range(df.shape[0]), y = "y_new", ax=ax[1], label = "Our method", lw = 0.5)
ax[1] = sns.lineplot(data = df, x = range(df.shape[0]), y = "y_gd_cd", ax=ax[1], label = "GD with Central Difference", lw = 0.5)

ax[1] = utility.custom_figure_axis(ax[1], show_ticks = True, rotation =0, tick_fontsize = 10, label_fontsize = 10, legend_fontsize = 3)


ax[1].legend(ncol = 1, fontsize=3, frameon=False)
ax[1].set_ylabel("Optimized y", labelpad=1)
ax[1].set_xlabel("(-5,-5) to (5,5)", labelpad=1)

# ax[0].set_yscale("log")



plt.tight_layout()
plt.savefig("simulated2_new.pdf", dpi = 300, transparent=False, bbox_inches="tight")

# %%
# res = {"model": model, "history_autograd": history_autograd, "history_proposed": history_proposed, "history_gd": history_gd, "result": df}

# # Save (pickle) the dictionary to a file
# with open("simulated2_new.pkl", "wb") as file:
#     pickle.dump(res, file)

# %% [markdown]
# ##### Define error function

# %%
import numpy as np

def compute_error_metrics(series):
    """
    Compute various error metrics with respect to zero.

    Parameters:
    series (array-like): List or NumPy array of numerical values.

    Returns:
    dict: Dictionary containing various error metrics.
    """
    series = np.array(series)

    metrics = {
        "Mean Absolute Error (MAE)": np.mean(np.abs(series)),
        "Root Mean Square Error (RMSE)": np.sqrt(np.mean(series ** 2)),
        # "Mean Squared Error (MSE)": np.mean(series ** 2),
        # "Median Absolute Deviation (MAD)": np.median(np.abs(series)),
        # "Maximum Absolute Error (MaxAE)": np.max(np.abs(series))
    }
    
    return metrics

# %% [markdown]
# ##### Distance from global minimum at 0 for proposed methoed

# %%
# Example usage
error_metrics = compute_error_metrics(df["y_new"])


# Print the results
for metric, value in error_metrics.items():
    print(f"The {metric} distance from global minimum at 0: {value:.3e}")
# Out:
# The Mean Absolute Error (MAE) distance from global minimum at 0: 2.404e+00
# The Root Mean Square Error (RMSE) distance from global minimum at 0: 4.406e+00

# %% [markdown]
# ##### Distance from global minimum at 0  with autograd

# %%
# Example usage
error_metrics = compute_error_metrics(df["y_autograd"])


# Print the results
for metric, value in error_metrics.items():
    print(f"The {metric} distance from global minimum at 0: {value:.3e}")
# Out:
# The Mean Absolute Error (MAE) distance from global minimum at 0: 6.659e+00
# The Root Mean Square Error (RMSE) distance from global minimum at 0: 1.315e+01

# %% [markdown]
# ##### Distance from global minimum at 0 for central difference with gradient descent

# %%
# Example usage
error_metrics = compute_error_metrics(df["y_gd_cd"])


# Print the results
for metric, value in error_metrics.items():
    print(f"The {metric} distance from global minimum at 0: {value:.3e}")
# Out:
# The Mean Absolute Error (MAE) distance from global minimum at 0: 6.659e+00
# The Root Mean Square Error (RMSE) distance from global minimum at 0: 1.315e+01
